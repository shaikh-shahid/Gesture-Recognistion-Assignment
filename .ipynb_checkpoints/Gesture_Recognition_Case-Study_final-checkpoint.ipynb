# %% [markdown]
# ## Deep Learning Course Project - Gesture Recognition
#
# ### Problem Statement
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# | Gesture | Corresponding Action |
# | --- | --- |
# | Thumbs Up | Increase the volume. |
# | Thumbs Down | Decrease the volume. |
# | Left Swipe | 'Jump' backwards 10 seconds. |
# | Right Swipe | 'Jump' forward 10 seconds. |
# | Stop | Pause the movie. |
#
# Each video is a sequence of 30 frames (or images).
#
# ### Objectives:
# 1. **Generator**:  The generator should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# 2. **Model**: Develop a model that is able to train without any errors which will be judged on the total number of parameters (as the inference(prediction) time should be less) and the accuracy achieved. As suggested by Snehansu, start training on a small amount of data and then proceed further.
#
# 3. **Write up**: This should contain the detailed procedure followed in choosing the final model. The write up should start with the reason for choosing the base model, then highlight the reasons and metrics taken into consideration to modify and experiment to arrive at the final model.

# %%
# Importing the necessary libraries

import numpy as np
import os
from imageio import imread
from skimage.transform import resize
#from scipy.misc import imresize
import datetime
import os
import warnings
warnings.filterwarnings("ignore")
import abc
from sys import getsizeof

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)
#tf.random.set_seed

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# importing some other libraries which will be needed for model building.

from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import optimizers
from keras.layers import Dropout

# %%
project_folder='/datasets/Project_data'

# %% [markdown]
# ##### Plotting

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
    # MOST IMPORTANT PART HERE - The generator function        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ## Sample Model

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam()
        #optimiser = 'sgd'
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %% [markdown]
# ##### Sample Cropping

# %%
test_generator=ModelConv3D1()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])   
axes[1].imshow(batch_data[3,15,:,:,:])

# %% [markdown]
# ## Experimenting with Image resolution, number of frames to use and batch_size

# %%
#conv_3d1.train_model(conv_3d1_model)

# %% [markdown]
# ### We had hit the limit on memory resources with image resolution of 160x160 with 30 frames and batch_size of 40...we get the below error
#
# ResourceExhaustedError: OOM when allocating tensor with shape[40,16,30,160,160] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc

# %%
print("Memory util is {} Gigs". format(getsizeof(np.zeros((40,16,30,160,160)))/(1024*1024*1024)))
# Out:
# Memory util is 3.662109524011612 Gigs

# %% [markdown]
# ##### So lets trade-off between these parameters

# %% [markdown]
# ##### Below are the experiments to see how training time is affected by image resolution, number of images in sequence and batch size

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=100,image_width=100)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=20,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 687813
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2024-01-31 20:50:42.861877: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-01-31 20:50:42.861939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14800 MB memory:  -> device: 0, name: Quadro RTX 5000, pci bus id: 0000:1e:00.0, compute capability: 7.5
# Epoch 1/2
# 2024-01-31 20:50:49.206743: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 34/34 [==============================] - ETA: 0s - loss: 1.5990 - categorical_accuracy: 0.4027
# Epoch 00001: val_loss improved from inf to 3.23053, saving model to model_init_2024-01-3120_50_43.005196/model-00001-1.59901-0.40271-3.23053-0.16000.h5
# 34/34 [==============================] - 181s 5s/step - loss: 1.5990 - categorical_accuracy: 0.4027 - val_loss: 3.2305 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/2
# 34/34 [==============================] - ETA: 0s - loss: 1.1095 - categorical_accuracy: 0.5430
# Epoch 00002: val_loss did not improve from 3.23053
# 34/34 [==============================] - 176s 5s/step - loss: 1.1095 - categorical_accuracy: 0.5430 - val_loss: 4.9491 - val_categorical_accuracy: 0.1500 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=15,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 45/45 [==============================] - ETA: 0s - loss: 1.6141 - categorical_accuracy: 0.4163
# Epoch 00001: val_loss improved from inf to 4.89802, saving model to model_init_2024-01-3120_56_44.618866/model-00001-1.61415-0.41629-4.89802-0.16000.h5
# 45/45 [==============================] - 197s 4s/step - loss: 1.6141 - categorical_accuracy: 0.4163 - val_loss: 4.8980 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 2/2
# 45/45 [==============================] - ETA: 0s - loss: 1.1094 - categorical_accuracy: 0.5551
# Epoch 00002: val_loss did not improve from 4.89802
# 45/45 [==============================] - 196s 4s/step - loss: 1.1094 - categorical_accuracy: 0.5551 - val_loss: 8.2804 - val_categorical_accuracy: 0.1600 - lr: 0.0010

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=2)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/2
# 23/23 [==============================] - ETA: 0s - loss: 1.5423 - categorical_accuracy: 0.4238
# Epoch 00001: val_loss improved from inf to 3.88626, saving model to model_init_2024-01-3121_03_20.908935/model-00001-1.54230-0.42383-3.88626-0.21000.h5
# 23/23 [==============================] - 108s 5s/step - loss: 1.5423 - categorical_accuracy: 0.4238 - val_loss: 3.8863 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/2
# 23/23 [==============================] - ETA: 0s - loss: 1.0924 - categorical_accuracy: 0.5822
# Epoch 00002: val_loss did not improve from 3.88626
# 23/23 [==============================] - 102s 5s/step - loss: 1.0924 - categorical_accuracy: 0.5822 - val_loss: 7.9436 - val_categorical_accuracy: 0.2200 - lr: 0.0010

# %% [markdown]
# - As we see from the above experiments **"image resolution"** and **number of frames** in sequence have more impact on training time than **batch_size**
# - We can consider the Batch Size around 15-40
# - We will change the resoulution 160*160, 120*120 according the model performance

# %% [markdown]
# ## Model 1
# ### Base Model - Batch Size = 40 and No. of Epochs = 15

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.SGD()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_12 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_18 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_12 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_13 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_13 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_19 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_14 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_20 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_15 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_21 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_9 (Dense)             (None, 64)                819264
#
#  batch_normalization_22 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  batch_normalization_23 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/15
# 17/17 [==============================] - ETA: 0s - loss: 1.8368 - categorical_accuracy: 0.3439
# Epoch 00001: val_loss improved from inf to 1.55146, saving model to model_init_2024-01-3121_06_54.683810/model-00001-1.83677-0.34389-1.55146-0.26000.h5
# 17/17 [==============================] - 137s 8s/step - loss: 1.8368 - categorical_accuracy: 0.3439 - val_loss: 1.5515 - val_categorical_accuracy: 0.2600 - lr: 0.0100
# Epoch 2/15
# 17/17 [==============================] - ETA: 0s - loss: 1.2192 - categorical_accuracy: 0.5566
# Epoch 00002: val_loss did not improve from 1.55146
# 17/17 [==============================] - 131s 8s/step - loss: 1.2192 - categorical_accuracy: 0.5566 - val_loss: 1.7129 - val_categorical_accuracy: 0.2500 - lr: 0.0100
# Epoch 3/15
# 17/17 [==============================] - ETA: 0s - loss: 1.0319 - categorical_accuracy: 0.6003
# Epoch 00003: val_loss did not improve from 1.55146
# 17/17 [==============================] - 128s 8s/step - loss: 1.0319 - categorical_accuracy: 0.6003 - val_loss: 2.2526 - val_categorical_accuracy: 0.1200 - lr: 0.0100
# Epoch 4/15
# 17/17 [==============================] - ETA: 0s - loss: 0.7751 - categorical_accuracy: 0.6953
# Epoch 00004: val_loss did not improve from 1.55146
# 17/17 [==============================] - 132s 8s/step - loss: 0.7751 - categorical_accuracy: 0.6953 - val_loss: 2.2536 - val_categorical_accuracy: 0.2100 - lr: 0.0100
# Epoch 5/15
# 17/17 [==============================] - ETA: 0s - loss: 0.7451 - categorical_accuracy: 0.7089
# Epoch 00005: val_loss did not improve from 1.55146
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 17/17 [==============================] - 133s 8s/step - loss: 0.7451 - categorical_accuracy: 0.7089 - val_loss: 2.9481 - val_categorical_accuracy: 0.1900 - lr: 0.0100
# Epoch 6/15
# 17/17 [==============================] - ETA: 0s - loss: 0.5816 - categorical_accuracy: 0.7934
# Epoch 00006: val_loss did not improve from 1.55146
# 17/17 [==============================] - 129s 8s/step - loss: 0.5816 - categorical_accuracy: 0.7934 - val_loss: 3.0337 - val_categorical_accuracy: 0.1900 - lr: 0.0020
# Epoch 7/15
# 17/17 [==============================] - ETA: 0s - loss: 0.5073 - categorical_accuracy: 0.8265
# Epoch 00007: val_loss did not improve from 1.55146
# 17/17 [==============================] - 132s 8s/step - loss: 0.5073 - categorical_accuracy: 0.8265 - val_loss: 3.2333 - val_categorical_accuracy: 0.2200 - lr: 0.0020
# Epoch 8/15
# 17/17 [==============================] - ETA: 0s - loss: 0.4202 - categorical_accuracy: 0.8673
# Epoch 00008: val_loss did not improve from 1.55146
# 17/17 [==============================] - 134s 8s/step - loss: 0.4202 - categorical_accuracy: 0.8673 - val_loss: 3.2259 - val_categorical_accuracy: 0.2200 - lr: 0.0020
# Epoch 9/15
# 17/17 [==============================] - ETA: 0s - loss: 0.4277 - categorical_accuracy: 0.8597
# Epoch 00010: val_loss did not improve from 1.55146
# 17/17 [==============================] - 131s 8s/step - loss: 0.4277 - categorical_accuracy: 0.8597 - val_loss: 3.2117 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-04
# Epoch 11/15
# 17/17 [==============================] - ETA: 0s - loss: 0.3741 - categorical_accuracy: 0.8839
# Epoch 00011: val_loss did not improve from 1.55146
# 17/17 [==============================] - 131s 8s/step - loss: 0.3741 - categorical_accuracy: 0.8839 - val_loss: 3.2029 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-04
# Epoch 00011: early stopping

# %%
plot(history_model1)

# %% [markdown]
# ##### Model is clearly overfitting. :(

# %% [markdown]
# ## Model 2
# ### Adding dropout layers - Batch Size = 20 and No. of Epochs = 25

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=25)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_16 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_16 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_24 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_17 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_17 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_25 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_17 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_18 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_18 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_26 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_18 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_19 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_19 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_27 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 12800)             0
#
#  dense_12 (Dense)            (None, 256)               3277056
#
#  batch_normalization_28 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  batch_normalization_29 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_14 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model,augment_data=True)
# Out:
# Total Params: 3638981
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.9478 - categorical_accuracy: 0.3575
# Epoch 00001: val_loss improved from inf to 2.63534, saving model to model_init_2024-01-3121_31_08.741476/model-00001-1.94779-0.35747-2.63534-0.23000.h5
# 34/34 [==============================] - 320s 10s/step - loss: 1.9478 - categorical_accuracy: 0.3575 - val_loss: 2.6353 - val_categorical_accuracy: 0.2300 - lr: 0.0100
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.5455 - categorical_accuracy: 0.4781
# Epoch 00002: val_loss improved from 2.63534 to 2.55911, saving model to model_init_2024-01-3121_31_08.741476/model-00002-1.54551-0.47813-2.55911-0.15000.h5
# 34/34 [==============================] - 255s 8s/step - loss: 1.5455 - categorical_accuracy: 0.4781 - val_loss: 2.5591 - val_categorical_accuracy: 0.1500 - lr: 0.0100
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.3186 - categorical_accuracy: 0.5513
# Epoch 00003: val_loss improved from 2.55911 to 1.60973, saving model to model_init_2024-01-3121_31_08.741476/model-00003-1.31862-0.55128-1.60973-0.42000.h5
# 34/34 [==============================] - 253s 8s/step - loss: 1.3186 - categorical_accuracy: 0.5513 - val_loss: 1.6097 - val_categorical_accuracy: 0.4200 - lr: 0.0100
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2996 - categorical_accuracy: 0.5287
# Epoch 00004: val_loss improved from 1.60973 to 1.49258, saving model to model_init_2024-01-3121_31_08.741476/model-00004-1.29957-0.52866-1.49258-0.37000.h5
# 34/34 [==============================] - 255s 8s/step - loss: 1.2996 - categorical_accuracy: 0.5287 - val_loss: 1.4926 - val_categorical_accuracy: 0.3700 - lr: 0.0100
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1886 - categorical_accuracy: 0.5528
# Epoch 00005: val_loss did not improve from 1.49258
# 34/34 [==============================] - 252s 8s/step - loss: 1.1886 - categorical_accuracy: 0.5528 - val_loss: 2.2171 - val_categorical_accuracy: 0.3300 - lr: 0.0100
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 1.0350 - categorical_accuracy: 0.6003
# Epoch 00006: val_loss did not improve from 1.49258
# 34/34 [==============================] - 255s 8s/step - loss: 1.0350 - categorical_accuracy: 0.6003 - val_loss: 2.3725 - val_categorical_accuracy: 0.2900 - lr: 0.0100
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9994 - categorical_accuracy: 0.6373
# Epoch 00007: val_loss did not improve from 1.49258
# 34/34 [==============================] - 253s 8s/step - loss: 0.9994 - categorical_accuracy: 0.6373 - val_loss: 2.4283 - val_categorical_accuracy: 0.2800 - lr: 0.0100
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8911 - categorical_accuracy: 0.6817
# Epoch 00008: val_loss did not improve from 1.49258
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
#
# Epoch 18/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6389 - categorical_accuracy: 0.7624
# Epoch 00018: val_loss improved from 0.92719 to 0.75059, saving model to model_init_2024-01-3121_31_08.741476/model-00018-0.63895-0.76244-0.75059-0.75000.h5
# 34/34 [==============================] - 251s 8s/step - loss: 0.6389 - categorical_accuracy: 0.7624 - val_loss: 0.7506 - val_categorical_accuracy: 0.7500 - lr: 0.0020
# Epoch 19/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6654 - categorical_accuracy: 0.7391
# Epoch 00019: val_loss did not improve from 0.75059
# 34/34 [==============================] - 252s 8s/step - loss: 0.6654 - categorical_accuracy: 0.7391 - val_loss: 0.8270 - val_categorical_accuracy: 0.6700 - lr: 0.0020
# Epoch 20/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6345 - categorical_accuracy: 0.7360
# Epoch 00020: val_loss did not improve from 0.75059
# 34/34 [==============================] - 253s 8s/step - loss: 0.6345 - categorical_accuracy: 0.7360 - val_loss: 0.8509 - val_categorical_accuracy: 0.7300 - lr: 0.0020
# Epoch 21/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6261 - categorical_accuracy: 0.7640
# Epoch 00021: val_loss improved from 0.75059 to 0.72982, saving model to model_init_2024-01-3121_31_08.741476/model-00021-0.62612-0.76395-0.72982-0.77000.h5
# 34/34 [==============================] - 255s 8s/step - loss: 0.6261 - categorical_accuracy: 0.7640 - val_loss: 0.7298 - val_categorical_accuracy: 0.7700 - lr: 0.0020
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6298 - categorical_accuracy: 0.7624
# Epoch 00022: val_loss improved from 0.72982 to 0.72388, saving model to model_init_2024-01-3121_31_08.741476/model-00022-0.62976-0.76244-0.72388-0.76000.h5
# 34/34 [==============================] - 254s 8s/step - loss: 0.6298 - categorical_accuracy: 0.7624 - val_loss: 0.7239 - val_categorical_accuracy: 0.7600 - lr: 0.0020
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6040 - categorical_accuracy: 0.7760
# Epoch 00023: val_loss improved from 0.72388 to 0.67898, saving model to model_init_2024-01-3121_31_08.741476/model-00023-0.60398-0.77602-0.67898-0.81000.h5
# 34/34 [==============================] - 251s 8s/step - loss: 0.6040 - categorical_accuracy: 0.7760 - val_loss: 0.6790 - val_categorical_accuracy: 0.8100 - lr: 0.0020
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5633 - categorical_accuracy: 0.7821
# Epoch 00024: val_loss improved from 0.67898 to 0.48708, saving model to model_init_2024-01-3121_31_08.741476/model-00024-0.56334-0.78205-0.48708-0.81000.h5
# 34/34 [==============================] - 252s 8s/step - loss: 0.5633 - categorical_accuracy: 0.7821 - val_loss: 0.4871 - val_categorical_accuracy: 0.8100 - lr: 0.0020
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5871 - categorical_accuracy: 0.7828
# Epoch 00025: val_loss did not improve from 0.48708
# 34/34 [==============================] - 250s 8s/step - loss: 0.5871 - categorical_accuracy: 0.7828 - val_loss: 0.8935 - val_categorical_accuracy: 0.6500 - lr: 0.0020

# %%
plot(history_model2)

# %% [markdown]
# - Best weights save automatically. The validation accuracy of 65% and training accuracy of 75%. Next we will try to reduce the filter size and image resolution and see if get better results.

# %% [markdown]
# ## Model 3
# ### Reduce filter size to (2,2,2) and image res to 120 x  120, - Batch Size = 30 and No. of Epochs = 25

# %%
class ModelConv3D3(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = tf.keras.optimizers.SGD(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_20 (Conv3D)          (None, 16, 120, 120, 16)  400
#
#  activation_20 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_30 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 8, 60, 60, 32)     4128
#
#  activation_21 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_31 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_22 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_32 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_23 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_23 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_33 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_23 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_5 (Flatten)         (None, 6272)              0
#
#  dense_15 (Dense)            (None, 256)               1605888
#
#  batch_normalization_34 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_16 (Dense)            (None, 256)               65792
#
#  batch_normalization_35 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 23/23 [==============================] - ETA: 0s - loss: 2.7234 - categorical_accuracy: 0.2074
# Epoch 00001: val_loss improved from inf to 1.63102, saving model to model_init_2024-01-3123_17_40.563922/model-00001-2.72344-0.20739-1.63102-0.15000.h5
# 23/23 [==============================] - 177s 8s/step - loss: 2.7234 - categorical_accuracy: 0.2074 - val_loss: 1.6310 - val_categorical_accuracy: 0.1500 - lr: 2.0000e-04
# Epoch 2/25
# 23/23 [==============================] - ETA: 0s - loss: 2.7368 - categorical_accuracy: 0.1991
# Epoch 00002: val_loss did not improve from 1.63102
# 23/23 [==============================] - 176s 8s/step - loss: 2.7368 - categorical_accuracy: 0.1991 - val_loss: 1.6710 - val_categorical_accuracy: 0.1300 - lr: 2.0000e-04
# Epoch 3/25
# 23/23 [==============================] - ETA: 0s - loss: 2.6023 - categorical_accuracy: 0.2496
# Epoch 00003: val_loss did not improve from 1.63102
# 23/23 [==============================] - 178s 8s/step - loss: 2.6023 - categorical_accuracy: 0.2496 - val_loss: 1.7202 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 4/25
# 23/23 [==============================] - ETA: 0s - loss: 2.5927 - categorical_accuracy: 0.2376
# Epoch 00004: val_loss did not improve from 1.63102
# 23/23 [==============================] - 258s 12s/step - loss: 2.5927 - categorical_accuracy: 0.2376 - val_loss: 1.7144 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 5/25
# 23/23 [==============================] - ETA: 0s - loss: 2.4198 - categorical_accuracy: 0.2617
# Epoch 00005: val_loss did not improve from 1.63102
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 23/23 [==============================] - 434s 20s/step - loss: 2.4198 - categorical_accuracy: 0.2617 - val_loss: 1.8020 - val_categorical_accuracy: 0.2200 - lr: 2.0000e-04
# Epoch 6/25
# 23/23 [==============================] - ETA: 0s - loss: 2.4635 - categorical_accuracy: 0.2496
# Epoch 00006: val_loss did not improve from 1.63102
# 23/23 [==============================] - 443s 20s/step - loss: 2.4635 - categorical_accuracy: 0.2496 - val_loss: 1.8591 - val_categorical_accuracy: 0.1700 - lr: 4.0000e-05
# Epoch 7/25
# 23/23 [==============================] - ETA: 0s - loss: 2.4491 - categorical_accuracy: 0.2541
# Epoch 00007: val_loss did not improve from 1.63102
# 23/23 [==============================] - 446s 20s/step - loss: 2.4491 - categorical_accuracy: 0.2541 - val_loss: 1.8987 - val_categorical_accuracy: 0.2900 - lr: 4.0000e-05
# Epoch 8/25
# 23/23 [==============================] - ETA: 0s - loss: 2.3586 - categorical_accuracy: 0.2670
# Epoch 00008: val_loss did not improve from 1.63102
# 23/23 [==============================] - 399s 18s/step - loss: 2.3586 - categorical_accuracy: 0.2670 - val_loss: 2.0534 - val_categorical_accuracy: 0.2400 - lr: 4.0000e-05
# Epoch 9/25
# 23/23 [==============================] - ETA: 0s - loss: 2.3291 - categorical_accuracy: 0.2798
# Epoch 00009: val_loss did not improve from 1.63102
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 23/23 [==============================] - 411s 19s/step - loss: 2.3291 - categorical_accuracy: 0.2798 - val_loss: 2.1012 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 10/25
# 23/23 [==============================] - ETA: 0s - loss: 2.2798 - categorical_accuracy: 0.2851
# Epoch 00010: val_loss did not improve from 1.63102
# 23/23 [==============================] - 395s 18s/step - loss: 2.2798 - categorical_accuracy: 0.2851 - val_loss: 2.2053 - val_categorical_accuracy: 0.1700 - lr: 8.0000e-06
# Epoch 11/25
# 23/23 [==============================] - ETA: 0s - loss: 2.3442 - categorical_accuracy: 0.2805
# Epoch 00011: val_loss did not improve from 1.63102
# 23/23 [==============================] - 423s 19s/step - loss: 2.3442 - categorical_accuracy: 0.2805 - val_loss: 2.2947 - val_categorical_accuracy: 0.2100 - lr: 8.0000e-06
# Epoch 00011: early stopping

# %%
plot(history_model3)

# %% [markdown]
# ##### Model has a  best validation accuracy of 72% and training accuracy of 76% . Also we were able to reduce the parameter size by half the earlier model. Let's trying adding more layers

# %% [markdown]
# ## Model 4 -
# ### Adding more layers - Batch Size = 20 and No. of Epochs = 25

# %%
class ModelConv3D4(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d4=ModelConv3D4()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=120,image_width=120)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d4_model=conv_3d4.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d4_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_24 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_24 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_36 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  conv3d_25 (Conv3D)          (None, 16, 120, 120, 16)  6928
#
#  activation_25 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_37 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_24 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_26 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_26 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_38 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  conv3d_27 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_27 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_39 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_25 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_28 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_28 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_40 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  conv3d_29 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_29 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_41 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_26 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_30 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_30 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_42 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  conv3d_31 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_31 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_43 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_27 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_6 (Flatten)         (None, 6272)              0
#
#  dense_18 (Dense)            (None, 256)               1605888
#
#  batch_normalization_44 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_19 (Dense)            (None, 256)               65792
#
#  batch_normalization_45 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_20 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)
# Out:
# Total Params: 2556533
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.9961 - categorical_accuracy: 0.3673
# Epoch 00001: val_loss improved from inf to 3.08702, saving model to model_init_2024-02-0100_20_08.919706/model-00001-1.99610-0.36727-3.08702-0.27000.h5
# 34/34 [==============================] - 430s 13s/step - loss: 1.9961 - categorical_accuracy: 0.3673 - val_loss: 3.0870 - val_categorical_accuracy: 0.2700 - lr: 0.0010
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.6334 - categorical_accuracy: 0.4434
# Epoch 00002: val_loss did not improve from 3.08702
# 34/34 [==============================] - 604s 18s/step - loss: 1.6334 - categorical_accuracy: 0.4434 - val_loss: 3.5590 - val_categorical_accuracy: 0.2300 - lr: 0.0010
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.3908 - categorical_accuracy: 0.4970
# Epoch 00003: val_loss did not improve from 3.08702
# 34/34 [==============================] - 873s 26s/step - loss: 1.3908 - categorical_accuracy: 0.4970 - val_loss: 4.9597 - val_categorical_accuracy: 0.1400 - lr: 0.0010
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2532 - categorical_accuracy: 0.5558
# Epoch 00004: val_loss did not improve from 3.08702
# 34/34 [==============================] - 886s 27s/step - loss: 1.2532 - categorical_accuracy: 0.5558 - val_loss: 6.0109 - val_categorical_accuracy: 0.1500 - lr: 0.0010
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 1.0744 - categorical_accuracy: 0.6109
# Epoch 00005: val_loss did not improve from 3.08702
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 695s 21s/step - loss: 1.0744 - categorical_accuracy: 0.6109 - val_loss: 5.5922 - val_categorical_accuracy: 0.2000 - lr: 0.0010
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8809 - categorical_accuracy: 0.6750
# Epoch 00006: val_loss did not improve from 3.08702
# 34/34 [==============================] - 864s 26s/step - loss: 0.8809 - categorical_accuracy: 0.6750 - val_loss: 5.8739 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8213 - categorical_accuracy: 0.7074
# Epoch 00007: val_loss did not improve from 3.08702
# 34/34 [==============================] - 713s 22s/step - loss: 0.8213 - categorical_accuracy: 0.7074 - val_loss: 6.6563 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7659 - categorical_accuracy: 0.7202
# Epoch 00008: val_loss did not improve from 3.08702
# 34/34 [==============================] - 804s 24s/step - loss: 0.7659 - categorical_accuracy: 0.7202 - val_loss: 5.6910 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7602 - categorical_accuracy: 0.7104
# Epoch 00009: val_loss did not improve from 3.08702
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 1058s 32s/step - loss: 0.7602 - categorical_accuracy: 0.7104 - val_loss: 6.0416 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6912 - categorical_accuracy: 0.7504
# Epoch 00010: val_loss did not improve from 3.08702
# 34/34 [==============================] - 703s 21s/step - loss: 0.6912 - categorical_accuracy: 0.7504 - val_loss: 5.6322 - val_categorical_accuracy: 0.2200 - lr: 4.0000e-05
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7090 - categorical_accuracy: 0.7383
# Epoch 00011: val_loss did not improve from 3.08702
# 34/34 [==============================] - 174s 5s/step - loss: 0.7090 - categorical_accuracy: 0.7383 - val_loss: 4.9887 - val_categorical_accuracy: 0.2300 - lr: 4.0000e-05
# Epoch 00011: early stopping

# %%
plot(history_model4)

# %% [markdown]
# ##### With more layers we dont see much performance improvement. We get a best validation accuracy of 73% . Let's try adding dropouts at the convolution layers

# %% [markdown]
# ## Model 5
# ### Adding dropout at convolution layers

# %%
class ModelConv3D5(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d5=ModelConv3D5()
conv_3d5.initialize_path(project_folder)
conv_3d5.initialize_image_properties(image_height=120,image_width=120)
conv_3d5.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=15)
conv_3d5_model=conv_3d5.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.25)
conv_3d5_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_32 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_32 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_46 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  conv3d_33 (Conv3D)          (None, 16, 120, 120, 16)  6928
#
#  activation_33 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_47 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_28 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  dropout_14 (Dropout)        (None, 8, 60, 60, 16)     0
#
#  conv3d_34 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_34 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_48 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  conv3d_35 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_35 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_49 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_29 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  dropout_15 (Dropout)        (None, 4, 30, 30, 32)     0
#
#  conv3d_36 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_36 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_50 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  conv3d_37 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_37 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_51 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_30 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  dropout_16 (Dropout)        (None, 2, 15, 15, 64)     0
#
#  conv3d_38 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_38 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_52 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  conv3d_39 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_39 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_53 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_31 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  dropout_17 (Dropout)        (None, 1, 7, 7, 128)      0
#
#  flatten_7 (Flatten)         (None, 6272)              0
#
#  dense_21 (Dense)            (None, 256)               1605888
#
#  batch_normalization_54 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_22 (Dense)            (None, 256)               65792
#
#  batch_normalization_55 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
print("Total Params:", conv_3d5_model.count_params())
history_model5=conv_3d5.train_model(conv_3d5_model,augment_data=True)
# Out:
# Total Params: 2556533
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4199 - categorical_accuracy: 0.8424
# Epoch 00001: val_loss improved from inf to 3.16914, saving model to model_init_2024-02-0107_32_31.712978/model-00001-0.41993-0.84238-3.16914-0.31000.h5
# 34/34 [==============================] - 389s 12s/step - loss: 0.4199 - categorical_accuracy: 0.8424 - val_loss: 3.1691 - val_categorical_accuracy: 0.3100 - lr: 4.0000e-05
# Epoch 2/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4169 - categorical_accuracy: 0.8462
# Epoch 00002: val_loss did not improve from 3.16914
# 34/34 [==============================] - 399s 12s/step - loss: 0.4169 - categorical_accuracy: 0.8462 - val_loss: 3.2825 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 3/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4041 - categorical_accuracy: 0.8537
# Epoch 00003: val_loss improved from 3.16914 to 2.86302, saving model to model_init_2024-02-0107_32_31.712978/model-00003-0.40413-0.85370-2.86302-0.37000.h5
# 34/34 [==============================] - 402s 12s/step - loss: 0.4041 - categorical_accuracy: 0.8537 - val_loss: 2.8630 - val_categorical_accuracy: 0.3700 - lr: 4.0000e-05
# Epoch 4/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3847 - categorical_accuracy: 0.8552
# Epoch 00004: val_loss improved from 2.86302 to 2.79503, saving model to model_init_2024-02-0107_32_31.712978/model-00004-0.38469-0.85520-2.79503-0.36000.h5
# 34/34 [==============================] - 403s 12s/step - loss: 0.3847 - categorical_accuracy: 0.8552 - val_loss: 2.7950 - val_categorical_accuracy: 0.3600 - lr: 4.0000e-05
# Epoch 5/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4034 - categorical_accuracy: 0.8499
# Epoch 00005: val_loss improved from 2.79503 to 2.39496, saving model to model_init_2024-02-0107_32_31.712978/model-00005-0.40342-0.84992-2.39496-0.38000.h5
# 34/34 [==============================] - 383s 12s/step - loss: 0.4034 - categorical_accuracy: 0.8499 - val_loss: 2.3950 - val_categorical_accuracy: 0.3800 - lr: 4.0000e-05
# Epoch 6/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3883 - categorical_accuracy: 0.8560
# Epoch 00006: val_loss improved from 2.39496 to 2.19536, saving model to model_init_2024-02-0107_32_31.712978/model-00006-0.38829-0.85596-2.19536-0.39000.h5
# 34/34 [==============================] - 383s 12s/step - loss: 0.3883 - categorical_accuracy: 0.8560 - val_loss: 2.1954 - val_categorical_accuracy: 0.3900 - lr: 4.0000e-05
# Epoch 7/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3592 - categorical_accuracy: 0.8718
# Epoch 00007: val_loss improved from 2.19536 to 1.92157, saving model to model_init_2024-02-0107_32_31.712978/model-00007-0.35918-0.87179-1.92157-0.45000.h5
# 34/34 [==============================] - 405s 12s/step - loss: 0.3592 - categorical_accuracy: 0.8718 - val_loss: 1.9216 - val_categorical_accuracy: 0.4500 - lr: 4.0000e-05
# Epoch 8/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3753 - categorical_accuracy: 0.8673
# Epoch 00008: val_loss did not improve from 1.92157
# 34/34 [==============================] - 396s 12s/step - loss: 0.3753 - categorical_accuracy: 0.8673 - val_loss: 2.0488 - val_categorical_accuracy: 0.4000 - lr: 4.0000e-05
# Epoch 9/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3851 - categorical_accuracy: 0.8590
# Epoch 00009: val_loss improved from 1.92157 to 1.39306, saving model to model_init_2024-02-0107_32_31.712978/model-00009-0.38506-0.85897-1.39306-0.56000.h5
# 34/34 [==============================] - 392s 12s/step - loss: 0.3851 - categorical_accuracy: 0.8590 - val_loss: 1.3931 - val_categorical_accuracy: 0.5600 - lr: 4.0000e-05
# Epoch 10/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3976 - categorical_accuracy: 0.8529
# Epoch 00010: val_loss did not improve from 1.39306
# 34/34 [==============================] - 393s 12s/step - loss: 0.3976 - categorical_accuracy: 0.8529 - val_loss: 1.4405 - val_categorical_accuracy: 0.5200 - lr: 4.0000e-05
# Epoch 11/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3683 - categorical_accuracy: 0.8582
# Epoch 00011: val_loss did not improve from 1.39306
# 34/34 [==============================] - 388s 12s/step - loss: 0.3683 - categorical_accuracy: 0.8582 - val_loss: 1.4580 - val_categorical_accuracy: 0.5100 - lr: 4.0000e-05
# Epoch 12/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3474 - categorical_accuracy: 0.8763
# Epoch 00012: val_loss did not improve from 1.39306
# 34/34 [==============================] - 377s 11s/step - loss: 0.3474 - categorical_accuracy: 0.8763 - val_loss: 1.5138 - val_categorical_accuracy: 0.5000 - lr: 4.0000e-05
# Epoch 13/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3290 - categorical_accuracy: 0.8733
# Epoch 00013: val_loss improved from 1.39306 to 1.08835, saving model to model_init_2024-02-0107_32_31.712978/model-00013-0.32901-0.87330-1.08835-0.56000.h5
# 34/34 [==============================] - 359s 11s/step - loss: 0.3290 - categorical_accuracy: 0.8733 - val_loss: 1.0884 - val_categorical_accuracy: 0.5600 - lr: 4.0000e-05
# Epoch 14/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3474 - categorical_accuracy: 0.8763
# Epoch 00014: val_loss did not improve from 1.08835
# 34/34 [==============================] - 178s 5s/step - loss: 0.3474 - categorical_accuracy: 0.8763 - val_loss: 1.2314 - val_categorical_accuracy: 0.6500 - lr: 4.0000e-05
# Epoch 15/15
# 34/34 [==============================] - ETA: 0s - loss: 0.3529 - categorical_accuracy: 0.8718
# Epoch 00015: val_loss improved from 1.08835 to 0.98031, saving model to model_init_2024-02-0107_32_31.712978/model-00015-0.35293-0.87179-0.98031-0.63000.h5
# 34/34 [==============================] - 180s 5s/step - loss: 0.3529 - categorical_accuracy: 0.8718 - val_loss: 0.9803 - val_categorical_accuracy: 0.6300 - lr: 4.0000e-05

# %%
plot(history_model5)

# %% [markdown]
# Overfitting again!! Adding dropouts has further reduced validation accuracy as the model doesn't seem to generalise well.

# %% [markdown]
# ##### All the experimental models above have more than 1 million parameters. Let's try to reduce the model size and see the performance

# %% [markdown]
# ## Model 6
# ### Reducing the number of parameters

# %%
class ModelConv3D6(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d6=ModelConv3D6()
conv_3d6.initialize_path(project_folder)
conv_3d6.initialize_image_properties(image_height=100,image_width=100)
conv_3d6.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=20)
conv_3d6_model=conv_3d6.define_model(dense_neurons=128,dropout=0.25)
conv_3d6_model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_52 (Conv3D)          (None, 16, 100, 100, 16)  1312
#
#  activation_52 (Activation)  (None, 16, 100, 100, 16)  0
#
#  batch_normalization_79 (Bat  (None, 16, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_44 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_53 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  activation_53 (Activation)  (None, 8, 50, 50, 32)     0
#
#  batch_normalization_80 (Bat  (None, 8, 50, 50, 32)    128
#  chNormalization)
#
#  max_pooling3d_45 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d_54 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  activation_54 (Activation)  (None, 4, 25, 25, 64)     0
#
#  batch_normalization_81 (Bat  (None, 4, 25, 25, 64)    256
#  chNormalization)
#
#  max_pooling3d_46 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  conv3d_55 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  activation_55 (Activation)  (None, 2, 12, 12, 128)    0
#
#  batch_normalization_82 (Bat  (None, 2, 12, 12, 128)   512
#  chNormalization)
#
#  max_pooling3d_47 (MaxPoolin  (None, 1, 6, 6, 128)     0
#  g3D)
#
#  flatten_12 (Flatten)        (None, 4608)              0
#
#  dense_35 (Dense)            (None, 128)               589952
#
#  batch_normalization_83 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_28 (Dropout)        (None, 128)               0
#
#  dense_36 (Dense)            (None, 128)               16512
#
#  batch_normalization_84 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_29 (Dropout)        (None, 128)               0
#
#  dense_37 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 696,645
# Trainable params: 695,653
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", conv_3d6_model.count_params())
history_model6=conv_3d6.train_model(conv_3d6_model,augment_data=True)
# Out:
# Total Params: 696645
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.7401 - categorical_accuracy: 0.3537
# Epoch 00001: val_loss improved from inf to 1.85756, saving model to model_init_2024-02-0109_03_12.126113/model-00001-1.74009-0.35370-1.85756-0.16000.h5
# 34/34 [==============================] - 174s 5s/step - loss: 1.7401 - categorical_accuracy: 0.3537 - val_loss: 1.8576 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3178 - categorical_accuracy: 0.5030
# Epoch 00002: val_loss did not improve from 1.85756
# 34/34 [==============================] - 171s 5s/step - loss: 1.3178 - categorical_accuracy: 0.5030 - val_loss: 2.4751 - val_categorical_accuracy: 0.1400 - lr: 2.0000e-04
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0719 - categorical_accuracy: 0.5830
# Epoch 00003: val_loss did not improve from 1.85756
# 34/34 [==============================] - 173s 5s/step - loss: 1.0719 - categorical_accuracy: 0.5830 - val_loss: 3.0477 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9467 - categorical_accuracy: 0.6403
# Epoch 00004: val_loss did not improve from 1.85756
# 34/34 [==============================] - 171s 5s/step - loss: 0.9467 - categorical_accuracy: 0.6403 - val_loss: 3.7523 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8026 - categorical_accuracy: 0.6916
# Epoch 00005: val_loss did not improve from 1.85756
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 295s 9s/step - loss: 0.8026 - categorical_accuracy: 0.6916 - val_loss: 4.1117 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6927 - categorical_accuracy: 0.7489
# Epoch 00006: val_loss did not improve from 1.85756
# 34/34 [==============================] - 322s 10s/step - loss: 0.6927 - categorical_accuracy: 0.7489 - val_loss: 4.5852 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6532 - categorical_accuracy: 0.7541
# Epoch 00007: val_loss did not improve from 1.85756
# 34/34 [==============================] - 329s 10s/step - loss: 0.6532 - categorical_accuracy: 0.7541 - val_loss: 4.6895 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6364 - categorical_accuracy: 0.7579
# Epoch 00008: val_loss did not improve from 1.85756
# 34/34 [==============================] - 320s 10s/step - loss: 0.6364 - categorical_accuracy: 0.7579 - val_loss: 4.9356 - val_categorical_accuracy: 0.1300 - lr: 4.0000e-05
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6516 - categorical_accuracy: 0.7481
# Epoch 00009: val_loss did not improve from 1.85756
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 326s 10s/step - loss: 0.6516 - categorical_accuracy: 0.7481 - val_loss: 4.9578 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6223 - categorical_accuracy: 0.7692
# Epoch 00010: val_loss did not improve from 1.85756
# 34/34 [==============================] - 318s 10s/step - loss: 0.6223 - categorical_accuracy: 0.7692 - val_loss: 4.5201 - val_categorical_accuracy: 0.2100 - lr: 8.0000e-06
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6253 - categorical_accuracy: 0.7602
# Epoch 00011: val_loss did not improve from 1.85756
# 34/34 [==============================] - 308s 9s/step - loss: 0.6253 - categorical_accuracy: 0.7602 - val_loss: 4.1528 - val_categorical_accuracy: 0.2300 - lr: 8.0000e-06
# Epoch 00011: early stopping

# %%
plot(history_model6)

# %% [markdown]
# ###### For the above low memory foot print model, we get the best validation accuracy of 76%

# %% [markdown]
# ## Model 7 - Reducing the number of parameters again

# %%
class ModelConv3D7(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d7=ModelConv3D7()
conv_3d7.initialize_path(project_folder)
conv_3d7.initialize_image_properties(image_height=120,image_width=120)
conv_3d7.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d7_model=conv_3d7.define_model(dense_neurons=64,dropout=0.25)
conv_3d7_model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_56 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_56 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_85 (Bat  (None, 16, 120, 120, 16)  64
#  chNormalization)
#
#  max_pooling3d_48 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_57 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_57 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_86 (Bat  (None, 8, 60, 60, 32)    128
#  chNormalization)
#
#  max_pooling3d_49 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_58 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_58 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_87 (Bat  (None, 4, 30, 30, 64)    256
#  chNormalization)
#
#  max_pooling3d_50 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_59 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_59 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_88 (Bat  (None, 2, 15, 15, 128)   512
#  chNormalization)
#
#  max_pooling3d_51 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_13 (Flatten)        (None, 6272)              0
#
#  dense_38 (Dense)            (None, 64)                401472
#
#  batch_normalization_89 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_30 (Dropout)        (None, 64)                0
#
#  dense_39 (Dense)            (None, 64)                4160
#
#  batch_normalization_90 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_31 (Dropout)        (None, 64)                0
#
#  dense_40 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 504,709
# Trainable params: 503,973
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d7_model.count_params())
history_model7=conv_3d7.train_model(conv_3d7_model,augment_data=True)
# Out:
# Total Params: 504709
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.8174 - categorical_accuracy: 0.3484
# Epoch 00001: val_loss improved from inf to 1.86315, saving model to model_init_2024-02-0109_51_45.974995/model-00001-1.81736-0.34842-1.86315-0.21000.h5
# 34/34 [==============================] - 375s 11s/step - loss: 1.8174 - categorical_accuracy: 0.3484 - val_loss: 1.8632 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2539 - categorical_accuracy: 0.5083
# Epoch 00002: val_loss did not improve from 1.86315
# 34/34 [==============================] - 356s 11s/step - loss: 1.2539 - categorical_accuracy: 0.5083 - val_loss: 2.9552 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.0276 - categorical_accuracy: 0.5965
# Epoch 00003: val_loss did not improve from 1.86315
# 34/34 [==============================] - 355s 11s/step - loss: 1.0276 - categorical_accuracy: 0.5965 - val_loss: 3.2639 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8808 - categorical_accuracy: 0.6659
# Epoch 00004: val_loss did not improve from 1.86315
# 34/34 [==============================] - 386s 12s/step - loss: 0.8808 - categorical_accuracy: 0.6659 - val_loss: 4.2365 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8441 - categorical_accuracy: 0.6719
# Epoch 00005: val_loss did not improve from 1.86315
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 387s 12s/step - loss: 0.8441 - categorical_accuracy: 0.6719 - val_loss: 4.5387 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6975 - categorical_accuracy: 0.7413
# Epoch 00006: val_loss did not improve from 1.86315
# 34/34 [==============================] - 398s 12s/step - loss: 0.6975 - categorical_accuracy: 0.7413 - val_loss: 5.3848 - val_categorical_accuracy: 0.1900 - lr: 4.0000e-05
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6839 - categorical_accuracy: 0.7285
# Epoch 00007: val_loss did not improve from 1.86315
# 34/34 [==============================] - 402s 12s/step - loss: 0.6839 - categorical_accuracy: 0.7285 - val_loss: 5.6629 - val_categorical_accuracy: 0.2400 - lr: 4.0000e-05
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6583 - categorical_accuracy: 0.7594
# Epoch 00008: val_loss did not improve from 1.86315
# 34/34 [==============================] - 389s 12s/step - loss: 0.6583 - categorical_accuracy: 0.7594 - val_loss: 5.9436 - val_categorical_accuracy: 0.2200 - lr: 4.0000e-05
# Epoch 9/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6410 - categorical_accuracy: 0.7534
# Epoch 00009: val_loss did not improve from 1.86315
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 387s 12s/step - loss: 0.6410 - categorical_accuracy: 0.7534 - val_loss: 5.6945 - val_categorical_accuracy: 0.2600 - lr: 4.0000e-05
# Epoch 10/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6375 - categorical_accuracy: 0.7647
# Epoch 00010: val_loss did not improve from 1.86315
# 34/34 [==============================] - 333s 10s/step - loss: 0.6375 - categorical_accuracy: 0.7647 - val_loss: 4.6857 - val_categorical_accuracy: 0.2900 - lr: 8.0000e-06
# Epoch 11/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6502 - categorical_accuracy: 0.7662
# Epoch 00011: val_loss did not improve from 1.86315
# 34/34 [==============================] - 325s 10s/step - loss: 0.6502 - categorical_accuracy: 0.7662 - val_loss: 4.2064 - val_categorical_accuracy: 0.2300 - lr: 8.0000e-06
# Epoch 00011: early stopping

# %%
plot(history_model7)

# %% [markdown]
# ###### For the above low memory foot print model the best validation accuracy of 76%

# %% [markdown]
# ## Model 8 - CNN- LSTM Model

# %%
class RNNCNN1(ModelBuilder):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        #model.add(TimeDistributed(Conv2D(512, (2, 2) , padding='valid', activation='relu')))
       # model.add(TimeDistributed(BatchNormalization()))
       # model.add(TimeDistributed(MaxPooling2D((2, 2))))

        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = tf.keras.optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_16 (TimeDi  (None, 18, 120, 120, 16)  448
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 18, 120, 120, 16)  64
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 18, 60, 60, 16)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 18, 60, 60, 32)   4640
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 18, 60, 60, 32)   128
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 18, 30, 30, 32)   0
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 18, 30, 30, 64)   18496
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 18, 30, 30, 64)   256
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 18, 15, 15, 64)   0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 18, 15, 15, 128)  73856
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 18, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 18, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_28 (TimeDi  (None, 18, 7, 7, 256)    295168
#  stributed)
#
#  time_distributed_29 (TimeDi  (None, 18, 7, 7, 256)    1024
#  stributed)
#
#  time_distributed_30 (TimeDi  (None, 18, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_31 (TimeDi  (None, 18, 2304)         0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 128)               1245696
#
#  dropout_32 (Dropout)        (None, 128)               0
#
#  dense_41 (Dense)            (None, 128)               16512
#
#  dropout_33 (Dropout)        (None, 128)               0
#
#  dense_42 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1,657,445
# Trainable params: 1,656,453
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model8=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)
# Out:
# Total Params: 1657445
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4180 - categorical_accuracy: 0.3741
# Epoch 00001: val_loss improved from inf to 1.82821, saving model to model_init_2024-02-0111_00_11.487460/model-00001-1.41805-0.37406-1.82821-0.21000.h5
# 34/34 [==============================] - 386s 12s/step - loss: 1.4180 - categorical_accuracy: 0.3741 - val_loss: 1.8282 - val_categorical_accuracy: 0.2100 - lr: 0.0010
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.2043 - categorical_accuracy: 0.4940
# Epoch 00002: val_loss did not improve from 1.82821
# 34/34 [==============================] - 432s 13s/step - loss: 1.2043 - categorical_accuracy: 0.4940 - val_loss: 2.1818 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9919 - categorical_accuracy: 0.5935
# Epoch 00003: val_loss did not improve from 1.82821
# 34/34 [==============================] - 429s 13s/step - loss: 0.9919 - categorical_accuracy: 0.5935 - val_loss: 2.1969 - val_categorical_accuracy: 0.1600 - lr: 0.0010
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8909 - categorical_accuracy: 0.6584
# Epoch 00004: val_loss did not improve from 1.82821
# 34/34 [==============================] - 438s 13s/step - loss: 0.8909 - categorical_accuracy: 0.6584 - val_loss: 3.0150 - val_categorical_accuracy: 0.2200 - lr: 0.0010
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7936 - categorical_accuracy: 0.6900
# Epoch 00005: val_loss did not improve from 1.82821
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 454s 14s/step - loss: 0.7936 - categorical_accuracy: 0.6900 - val_loss: 2.6679 - val_categorical_accuracy: 0.1900 - lr: 0.0010
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6158 - categorical_accuracy: 0.7632
# Epoch 00006: val_loss did not improve from 1.82821
# 34/34 [==============================] - 450s 14s/step - loss: 0.6158 - categorical_accuracy: 0.7632 - val_loss: 2.3059 - val_categorical_accuracy: 0.2700 - lr: 2.0000e-04
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5300 - categorical_accuracy: 0.8062
# Epoch 00007: val_loss did not improve from 1.82821
# 34/34 [==============================] - 434s 13s/step - loss: 0.5300 - categorical_accuracy: 0.8062 - val_loss: 2.2576 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5028 - categorical_accuracy: 0.8152
# Epoch 00008: val_loss did not improve from 1.82821
# 34/34 [==============================] - 448s 14s/step - loss: 0.5028 - categorical_accuracy: 0.8152 - val_loss: 2.3964 - val_categorical_accuracy: 0.2800 - lr: 2.0000e-04
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4324 - categorical_accuracy: 0.8401
# Epoch 00009: val_loss did not improve from 1.82821
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 454s 14s/step - loss: 0.4324 - categorical_accuracy: 0.8401 - val_loss: 1.9481 - val_categorical_accuracy: 0.4000 - lr: 2.0000e-04
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3846 - categorical_accuracy: 0.8643
# Epoch 00010: val_loss did not improve from 1.82821
# 34/34 [==============================] - 429s 13s/step - loss: 0.3846 - categorical_accuracy: 0.8643 - val_loss: 1.9158 - val_categorical_accuracy: 0.4200 - lr: 4.0000e-05
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3746 - categorical_accuracy: 0.8612
# Epoch 00011: val_loss improved from 1.82821 to 1.78544, saving model to model_init_2024-02-0111_00_11.487460/model-00011-0.37456-0.86124-1.78544-0.39000.h5
# 34/34 [==============================] - 447s 14s/step - loss: 0.3746 - categorical_accuracy: 0.8612 - val_loss: 1.7854 - val_categorical_accuracy: 0.3900 - lr: 4.0000e-05
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3396 - categorical_accuracy: 0.8801
# Epoch 00012: val_loss improved from 1.78544 to 1.59188, saving model to model_init_2024-02-0111_00_11.487460/model-00012-0.33965-0.88009-1.59188-0.47000.h5
# 34/34 [==============================] - 253s 8s/step - loss: 0.3396 - categorical_accuracy: 0.8801 - val_loss: 1.5919 - val_categorical_accuracy: 0.4700 - lr: 4.0000e-05
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3291 - categorical_accuracy: 0.8899
# Epoch 00013: val_loss improved from 1.59188 to 1.36425, saving model to model_init_2024-02-0111_00_11.487460/model-00013-0.32911-0.88989-1.36425-0.51000.h5
# 34/34 [==============================] - 204s 6s/step - loss: 0.3291 - categorical_accuracy: 0.8899 - val_loss: 1.3643 - val_categorical_accuracy: 0.5100 - lr: 4.0000e-05
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3059 - categorical_accuracy: 0.8944
# Epoch 00014: val_loss improved from 1.36425 to 1.00384, saving model to model_init_2024-02-0111_00_11.487460/model-00014-0.30586-0.89442-1.00384-0.59000.h5
# 34/34 [==============================] - 202s 6s/step - loss: 0.3059 - categorical_accuracy: 0.8944 - val_loss: 1.0038 - val_categorical_accuracy: 0.5900 - lr: 4.0000e-05
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2955 - categorical_accuracy: 0.9005
# Epoch 00015: val_loss did not improve from 1.00384
# 34/34 [==============================] - 373s 11s/step - loss: 0.2955 - categorical_accuracy: 0.9005 - val_loss: 1.0361 - val_categorical_accuracy: 0.6200 - lr: 4.0000e-05
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2962 - categorical_accuracy: 0.8974
# Epoch 00016: val_loss improved from 1.00384 to 0.83608, saving model to model_init_2024-02-0111_00_11.487460/model-00016-0.29624-0.89744-0.83608-0.70000.h5
# 34/34 [==============================] - 434s 13s/step - loss: 0.2962 - categorical_accuracy: 0.8974 - val_loss: 0.8361 - val_categorical_accuracy: 0.7000 - lr: 4.0000e-05
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3171 - categorical_accuracy: 0.8861
# Epoch 00017: val_loss improved from 0.83608 to 0.70972, saving model to model_init_2024-02-0111_00_11.487460/model-00017-0.31707-0.88612-0.70972-0.74000.h5
# 34/34 [==============================] - 411s 12s/step - loss: 0.3171 - categorical_accuracy: 0.8861 - val_loss: 0.7097 - val_categorical_accuracy: 0.7400 - lr: 4.0000e-05
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2781 - categorical_accuracy: 0.9125
# Epoch 00018: val_loss improved from 0.70972 to 0.67443, saving model to model_init_2024-02-0111_00_11.487460/model-00018-0.27807-0.91252-0.67443-0.76000.h5
# 34/34 [==============================] - 205s 6s/step - loss: 0.2781 - categorical_accuracy: 0.9125 - val_loss: 0.6744 - val_categorical_accuracy: 0.7600 - lr: 4.0000e-05
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3042 - categorical_accuracy: 0.8952
# Epoch 00019: val_loss did not improve from 0.67443
# 34/34 [==============================] - 198s 6s/step - loss: 0.3042 - categorical_accuracy: 0.8952 - val_loss: 0.6920 - val_categorical_accuracy: 0.7400 - lr: 4.0000e-05
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2719 - categorical_accuracy: 0.9133
# Epoch 00020: val_loss improved from 0.67443 to 0.64990, saving model to model_init_2024-02-0111_00_11.487460/model-00020-0.27187-0.91327-0.64990-0.75000.h5
# 34/34 [==============================] - 272s 8s/step - loss: 0.2719 - categorical_accuracy: 0.9133 - val_loss: 0.6499 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-05

# %%
plot(history_model8)

# %% [markdown]
# ##### For CNN - LSTM model we get a best validation accuracy of 91%

# %% [markdown]
# As we see more cases of overfitting, lets augment the data with ***slight rotation*** as well and run the same set of models again

# %% [markdown]
# ## Let's apply some data augmentation & check the model performance.

# %%
class ModelBuilderMoreAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderMoreAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])   
axes[1].imshow(batch_data[3,29,:,:,:])

# %% [markdown]
# ## Model 9 with Augmentation
# ### (3,3,3) Filter & 160x160 Image resolution - similar to Model 2

# %%
class ModelConv3D9(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d9=ModelConv3D9()
conv_3d9.initialize_path(project_folder)
conv_3d9.initialize_image_properties(image_height=160,image_width=160)
conv_3d9.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=20)
conv_3d9_model=conv_3d9.define_model(dense_neurons=256,dropout=0.5)
conv_3d9_model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_60 (Conv3D)          (None, 20, 160, 160, 16)  1312
#
#  activation_60 (Activation)  (None, 20, 160, 160, 16)  0
#
#  batch_normalization_96 (Bat  (None, 20, 160, 160, 16)  64
#  chNormalization)
#
#  max_pooling3d_52 (MaxPoolin  (None, 10, 80, 80, 16)   0
#  g3D)
#
#  conv3d_61 (Conv3D)          (None, 10, 80, 80, 32)    13856
#
#  activation_61 (Activation)  (None, 10, 80, 80, 32)    0
#
#  batch_normalization_97 (Bat  (None, 10, 80, 80, 32)   128
#  chNormalization)
#
#  max_pooling3d_53 (MaxPoolin  (None, 5, 40, 40, 32)    0
#  g3D)
#
#  conv3d_62 (Conv3D)          (None, 5, 40, 40, 64)     55360
#
#  activation_62 (Activation)  (None, 5, 40, 40, 64)     0
#
#  batch_normalization_98 (Bat  (None, 5, 40, 40, 64)    256
#  chNormalization)
#
#  max_pooling3d_54 (MaxPoolin  (None, 2, 20, 20, 64)    0
#  g3D)
#
#  conv3d_63 (Conv3D)          (None, 2, 20, 20, 128)    221312
#
#  activation_63 (Activation)  (None, 2, 20, 20, 128)    0
#
#  batch_normalization_99 (Bat  (None, 2, 20, 20, 128)   512
#  chNormalization)
#
#  max_pooling3d_55 (MaxPoolin  (None, 1, 10, 10, 128)   0
#  g3D)
#
#  flatten_15 (Flatten)        (None, 12800)             0
#
#  dense_43 (Dense)            (None, 256)               3277056
#
#  batch_normalization_100 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_34 (Dropout)        (None, 256)               0
#
#  dense_44 (Dense)            (None, 256)               65792
#
#  batch_normalization_101 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_35 (Dropout)        (None, 256)               0
#
#  dense_45 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d9_model.count_params())
history_model9=conv_3d9.train_model(conv_3d9_model,augment_data=True)
# Out:
# Total Params: 3638981
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 2.0937 - categorical_accuracy: 0.3431
# Epoch 00001: saving model to model_init_2024-02-0113_02_55.273788/model-00001-2.09371-0.34314-2.01769-0.21000.h5
# 34/34 [==============================] - 745s 22s/step - loss: 2.0937 - categorical_accuracy: 0.3431 - val_loss: 2.0177 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.5711 - categorical_accuracy: 0.4683
# Epoch 00002: saving model to model_init_2024-02-0113_02_55.273788/model-00002-1.57109-0.46833-2.53719-0.24000.h5
# 34/34 [==============================] - 715s 22s/step - loss: 1.5711 - categorical_accuracy: 0.4683 - val_loss: 2.5372 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3758 - categorical_accuracy: 0.5196
# Epoch 00003: saving model to model_init_2024-02-0113_02_55.273788/model-00003-1.37583-0.51961-3.80719-0.20000.h5
# 34/34 [==============================] - 262s 8s/step - loss: 1.3758 - categorical_accuracy: 0.5196 - val_loss: 3.8072 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 1.1530 - categorical_accuracy: 0.6086
# Epoch 00004: saving model to model_init_2024-02-0113_02_55.273788/model-00004-1.15305-0.60860-4.69289-0.23000.h5
# 34/34 [==============================] - 264s 8s/step - loss: 1.1530 - categorical_accuracy: 0.6086 - val_loss: 4.6929 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 1.1092 - categorical_accuracy: 0.6124
# Epoch 00005: saving model to model_init_2024-02-0113_02_55.273788/model-00005-1.10916-0.61237-5.73713-0.20000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 262s 8s/step - loss: 1.1092 - categorical_accuracy: 0.6124 - val_loss: 5.7371 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0
20
# 34/34 [==============================] - ETA: 0s - loss: 0.7383 - categorical_accuracy: 0.7330
# Epoch 00016: saving model to model_init_2024-02-0113_02_55.273788/model-00016-0.73830-0.73303-2.31890-0.35000.h5
# 34/34 [==============================] - 253s 8s/step - loss: 0.7383 - categorical_accuracy: 0.7330 - val_loss: 2.3189 - val_categorical_accuracy: 0.3500 - lr: 1.6000e-06
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7727 - categorical_accuracy: 0.7172
# Epoch 00017: saving model to model_init_2024-02-0113_02_55.273788/model-00017-0.77273-0.71719-1.61521-0.49000.h5
# 34/34 [==============================] - 251s 8s/step - loss: 0.7727 - categorical_accuracy: 0.7172 - val_loss: 1.6152 - val_categorical_accuracy: 0.4900 - lr: 1.6000e-06
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6987 - categorical_accuracy: 0.7526
# Epoch 00018: saving model to model_init_2024-02-0113_02_55.273788/model-00018-0.69868-0.75264-1.47455-0.52000.h5
# 34/34 [==============================] - 569s 17s/step - loss: 0.6987 - categorical_accuracy: 0.7526 - val_loss: 1.4746 - val_categorical_accuracy: 0.5200 - lr: 1.6000e-06
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7813 - categorical_accuracy: 0.7217
# Epoch 00019: saving model to model_init_2024-02-0113_02_55.273788/model-00019-0.78133-0.72172-1.07785-0.64000.h5
# 34/34 [==============================] - 595s 18s/step - loss: 0.7813 - categorical_accuracy: 0.7217 - val_loss: 1.0778 - val_categorical_accuracy: 0.6400 - lr: 1.6000e-06
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7920 - categorical_accuracy: 0.7059
# Epoch 00020: saving model to model_init_2024-02-0113_02_55.273788/model-00020-0.79199-0.70588-0.94095-0.70000.h5
# 34/34 [==============================] - 693s 21s/step - loss: 0.7920 - categorical_accuracy: 0.7059 - val_loss: 0.9409 - val_categorical_accuracy: 0.7000 - lr: 1.6000e-06

# %%
plot(history_model9)

# %% [markdown]
# ## Model 10 with Augmentation
# ### (2,2,2) Filter  & 120x120 Image resolution - similar to Model 3

# %%
class ModelConv3D10(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d10=ModelConv3D10()
conv_3d10.initialize_path(project_folder)
conv_3d10.initialize_image_properties(image_height=120,image_width=120)
conv_3d10.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d10_model=conv_3d10.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d10_model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_64 (Conv3D)          (None, 16, 120, 120, 16)  400
#
#  activation_64 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_102 (Ba  (None, 16, 120, 120, 16)  64
#  tchNormalization)
#
#  max_pooling3d_56 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_65 (Conv3D)          (None, 8, 60, 60, 32)     4128
#
#  activation_65 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_103 (Ba  (None, 8, 60, 60, 32)    128
#  tchNormalization)
#
#  max_pooling3d_57 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_66 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_66 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_104 (Ba  (None, 4, 30, 30, 64)    256
#  tchNormalization)
#
#  max_pooling3d_58 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_67 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_67 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_105 (Ba  (None, 2, 15, 15, 128)   512
#  tchNormalization)
#
#  max_pooling3d_59 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_16 (Flatten)        (None, 6272)              0
#
#  dense_46 (Dense)            (None, 256)               1605888
#
#  batch_normalization_106 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_36 (Dropout)        (None, 256)               0
#
#  dense_47 (Dense)            (None, 256)               65792
#
#  batch_normalization_107 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_37 (Dropout)        (None, 256)               0
#
#  dense_48 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params:
25
# 23/23 [==============================] - ETA: 0s - loss: 0.7665 - categorical_accuracy: 0.7217
# Epoch 00019: saving model to model_init_2024-02-0115_02_42.406084/model-00019-0.76653-0.72172-3.62163-0.28000.h5
# 23/23 [==============================] - 175s 8s/step - loss: 0.7665 - categorical_accuracy: 0.7217 - val_loss: 3.6216 - val_categorical_accuracy: 0.2800 - lr: 3.2000e-07
# Epoch 20/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8685 - categorical_accuracy: 0.6757
# Epoch 00020: saving model to model_init_2024-02-0115_02_42.406084/model-00020-0.86848-0.67572-3.05944-0.31000.h5
# 23/23 [==============================] - 171s 8s/step - loss: 0.8685 - categorical_accuracy: 0.6757 - val_loss: 3.0594 - val_categorical_accuracy: 0.3100 - lr: 3.2000e-07
# Epoch 21/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8735 - categorical_accuracy: 0.6817
# Epoch 00021: saving model to model_init_2024-02-0115_02_42.406084/model-00021-0.87346-0.68175-2.77882-0.34000.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.399999961104187e-08.
# 23/23 [==============================] - 175s 8s/step - loss: 0.8735 - categorical_accuracy: 0.6817 - val_loss: 2.7788 - val_categorical_accuracy: 0.3400 - lr: 3.2000e-07
# Epoch 22/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8137 - categorical_accuracy: 0.6991
# Epoch 00022: saving model to model_init_2024-02-0115_02_42.406084/model-00022-0.81370-0.69910-2.31520-0.38000.h5
# 23/23 [==============================] - 177s 8s/step - loss: 0.8137 - categorical_accuracy: 0.6991 - val_loss: 2.3152 - val_categorical_accuracy: 0.3800 - lr: 6.4000e-08
# Epoch 23/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8379 - categorical_accuracy: 0.6878
# Epoch 00023: saving model to model_init_2024-02-0115_02_42.406084/model-00023-0.83789-0.68778-2.19205-0.47000.h5
# 23/23 [==============================] - 264s 12s/step - loss: 0.8379 - categorical_accuracy: 0.6878 - val_loss: 2.1921 - val_categorical_accuracy: 0.4700 - lr: 6.4000e-08
# Epoch 24/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8324 - categorical_accuracy: 0.6938
# Epoch 00024: saving model to model_init_2024-02-0115_02_42.406084/model-00024-0.83243-0.69382-1.84653-0.48000.h5
# 23/23 [==============================] - 340s 15s/step - loss: 0.8324 - categorical_accuracy: 0.6938 - val_loss: 1.8465 - val_categorical_accuracy: 0.4800 - lr: 6.4000e-08
# Epoch 25/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8368 - categorical_accuracy: 0.6870
# Epoch 00025: saving model to model_init_2024-02-0115_02_42.406084/model-00025-0.83677-0.68703-1.65466-0.51000.h5
# 23/23 [==============================] - 374s 17s/step - loss: 0.8368 - categorical_accuracy: 0.6870 - val_loss: 1.6547 - val_categorical_accuracy: 0.5100 - lr: 6.4000e-08

# %%
plot(history_model10)

# %% [markdown]
# ## Model 11 with Augmentation
# ### Adding more layers - Similar to model 4

# %%
class ModelConv3D11(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d11=ModelConv3D11()
conv_3d11.initialize_path(project_folder)
conv_3d11.initialize_image_properties(image_height=120,image_width=120)
conv_3d11.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d11_model=conv_3d11.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.5)
conv_3d11_model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_68 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_68 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_108 (Ba  (None, 16, 120, 120, 16)  64
#  tchNormalization)
#
#  conv3d_69 (Conv3D)          (None, 16, 120, 120, 16)  6928
#
#  activation_69 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_109 (Ba  (None, 16, 120, 120, 16)  64
#  tchNormalization)
#
#  max_pooling3d_60 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_70 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_70 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_110 (Ba  (None, 8, 60, 60, 32)    128
#  tchNormalization)
#
#  conv3d_71 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_71 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_111 (Ba  (None, 8, 60, 60, 32)    128
#  tchNormalization)
#
#  max_pooling3d_61 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_72 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_72 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_112 (Ba  (None, 4, 30, 30, 64)    256
#  tchNormalization)
#
#  conv3d_73 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_73 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_113 (Ba  (None, 4, 30, 30, 64)    256
#  tchNormalization)
#
#  max_pooling3d_62 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_74 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_74 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_114 (Ba  (None, 2, 15, 15, 128)   512
#  tchNormalization)
#
#  conv3d_75 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_75 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_115 (Ba  (None, 2, 15, 15, 128)   512
#  tchNormalization)
#
#  max_pooling3d_63 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_17 (Flatten)        (None, 6272)              0
#
#  dense_49 (Dense)            (None, 256)               1605888
#
#  batch_normalization_116 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_38 (Dropout)        (None, 256)               0
#
#  dense_50 (Dense)            (None, 256)               65792
#
#  batch_normalization_117 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_39 (Dropout)        (None, 256)               0
#
#  dense_51 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
print("Total Params:", conv_3d11_model.count_params())
history_model11=conv_3d11.train_model(conv_3d11_model,augment_data=True)
# Out:
# Total Params: 2556533
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 2.1454 - categorical_accuracy: 0.3439
# Epoch 00001: saving model to model_init_2024-02-0116_53_27.994043/model-00001-2.14543-0.34389-1.91712-0.21000.h5
# 34/34 [==============================] - 341s 10s/step - loss: 2.1454 - categorical_accuracy: 0.3439 - val_loss: 1.9171 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.6736 - categorical_accuracy: 0.4510
# Epoch 00002: saving model to model_init_2024-02-0116_53_27.994043/model-00002-1.67359-0.45098-2.55539-0.19000.h5
# 34/34 [==============================] - 388s 12s/step - loss: 1.6736 - categorical_accuracy: 0.4510 - val_loss: 2.5554 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.4211 - categorical_accuracy: 0.5234
# Epoch 00003: saving model to model_init_2024-02-0116_53_27.994043/model-00003-1.42113-0.52338-2.85079-0.18000.h5
# 34/34 [==============================] - 399s 12s/step - loss: 1.4211 - categorical_accuracy: 0.5234 - val_loss: 2.8508 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 1.3322 - categorical_accuracy: 0.5294
# Epoch 00004: saving model to model_init_2024-02-0116_53_27.994043/model-00004-1.33219-0.52941-3.45085-0.18000.h5
# 34/34 [==============================] - 390s 12s/step - loss: 1.3322 - categorical_accuracy: 0.5294 - val_loss: 3.4508 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2070 - categorical_accuracy: 0.5890
# Epoch 00005: saving model to model_init_2024-02-0116_53_27.994043/model-00005-1.20702-0.58899-4.96913-0.16000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 399s 12s/step - loss: 1.2070 - categorical_accuracy: 0.5890 - val_loss: 4.9691 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 1.0465 - categorical_accuracy: 0.6222
# Epoch 00006: saving model to model_init_2024-02-0116_53_27.994043/model-00006-1.04649-0.62217-4.92383-0.16000.h5
# 34/34 [==============================] - 400s 12s/step - loss: 1.0465 - categorical_accuracy: 0.6222 - val_loss: 4.9238 - val_categorical_accuracy: 0.1600 - lr: 4.0000e-05
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9713 - categorical_accuracy: 0.6388
# Epoch 00007: saving model to model_init_2024-02-0116_53_27.994043/model-00007-0.97125-0.63876-4.72614-0.20000.h5
# 34/34 [==============================] - 399s 12s/step - loss: 0.9713 - categorical_accuracy: 0.6388 - val_loss: 4.7261 - val_categorical_accuracy: 0.2000 - lr: 4.0000e-05
# Epoch 8/25
# 34/34 [==============================] - ETA: 0s - loss: 0.
- lr: 1.6000e-06
# Epoch 18/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8496 - categorical_accuracy: 0.7006
# Epoch 00018: saving model to model_init_2024-02-0116_53_27.994043/model-00018-0.84962-0.70060-1.32017-0.53000.h5
# 34/34 [==============================] - 390s 12s/step - loss: 0.8496 - categorical_accuracy: 0.7006 - val_loss: 1.3202 - val_categorical_accuracy: 0.5300 - lr: 1.6000e-06
# Epoch 19/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8558 - categorical_accuracy: 0.6961
# Epoch 00019: saving model to model_init_2024-02-0116_53_27.994043/model-00019-0.85583-0.69608-1.16088-0.56000.h5
# 34/34 [==============================] - 400s 12s/step - loss: 0.8558 - categorical_accuracy: 0.6961 - val_loss: 1.1609 - val_categorical_accuracy: 0.5600 - lr: 1.6000e-06
# Epoch 20/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9056 - categorical_accuracy: 0.6735
# Epoch 00020: saving model to model_init_2024-02-0116_53_27.994043/model-00020-0.90559-0.67345-0.93143-0.63000.h5
# 34/34 [==============================] - 391s 12s/step - loss: 0.9056 - categorical_accuracy: 0.6735 - val_loss: 0.9314 - val_categorical_accuracy: 0.6300 - lr: 1.6000e-06
# Epoch 21/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8034 - categorical_accuracy: 0.7089
# Epoch 00021: saving model to model_init_2024-02-0116_53_27.994043/model-00021-0.80339-0.70890-0.84620-0.68000.h5
# 34/34 [==============================] - 399s 12s/step - loss: 0.8034 - categorical_accuracy: 0.7089 - val_loss: 0.8462 - val_categorical_accuracy: 0.6800 - lr: 1.6000e-06
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7758 - categorical_accuracy: 0.7112
# Epoch 00022: saving model to model_init_2024-02-0116_53_27.994043/model-00022-0.77582-0.71116-0.79034-0.72000.h5
# 34/34 [==============================] - 377s 11s/step - loss: 0.7758 - categorical_accuracy: 0.7112 - val_loss: 0.7903 - val_categorical_accuracy: 0.7200 - lr: 1.6000e-06
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8328 - categorical_accuracy: 0.6961
# Epoch 00023: saving model to model_init_2024-02-0116_53_27.994043/model-00023-0.83284-0.69608-0.73067-0.75000.h5
# 34/34 [==============================] - 389s 12s/step - loss: 0.8328 - categorical_accuracy: 0.6961 - val_loss: 0.7307 - val_categorical_accuracy: 0.7500 - lr: 1.6000e-06
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8578 - categorical_accuracy: 0.6772
# Epoch 00024: saving model to model_init_2024-02-0116_53_27.994043/model-00024-0.85781-0.67722-0.73280-0.75000.h5
# 34/34 [==============================] - 397s 12s/step - loss: 0.8578 - categorical_accuracy: 0.6772 - val_loss: 0.7328 - val_categorical_accuracy: 0.7500 - lr: 1.6000e-06
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8978 - categorical_accuracy: 0.6787
# Epoch 00025: saving model to model_init_2024-02-0116_53_27.994043/model-00025-0.89776-0.67873-0.76891-0.71000.h5
# 34/34 [==============================] - 393s 12s/step - loss: 0.8978 - categorical_accuracy: 0.6787 - val_loss: 0.7689 - val_categorical_accuracy: 0.7100 - lr: 1.6000e-06

# %%
plot(history_model11)

# %% [markdown]
# ## Model 12 with Augmentation
# ### Adding dropouts - Similar to Model 5

# %%
class ModelConv3D12(ModelBuilderMoreAugmentation):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        model.add(Dropout(dropout))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d12=ModelConv3D12()
conv_3d12.initialize_path(project_folder)
conv_3d12.initialize_image_properties(image_height=120,image_width=120)
conv_3d12.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d12_model=conv_3d12.define_model(filtersize=(3,3,3),dense_neurons=256,dropout=0.25)
conv_3d12_model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_76 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_76 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_118 (Ba  (None, 16, 120, 120, 16)  64
#  tchNormalization)
#
#  conv3d_77 (Conv3D)          (None, 16, 120, 120, 16)  6928
#
#  activation_77 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_119 (Ba  (None, 16, 120, 120, 16)  64
#  tchNormalization)
#
#  max_pooling3d_64 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  dropout_40 (Dropout)        (None, 8, 60, 60, 16)     0
#
#  conv3d_78 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_78 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_120 (Ba  (None, 8, 60, 60, 32)    128
#  tchNormalization)
#
#  conv3d_79 (Conv3D)          (None, 8, 60, 60, 32)     27680
#
#  activation_79 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_121 (Ba  (None, 8, 60, 60, 32)    128
#  tchNormalization)
#
#  max_pooling3d_65 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  dropout_41 (Dropout)        (None, 4, 30, 30, 32)     0
#
#  conv3d_80 (Conv3D)          (None, 4, 30, 30, 64)     55360
#
#  activation_80 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_122 (Ba  (None, 4, 30, 30, 64)    256
#  tchNormalization)
#
#  conv3d_81 (Conv3D)          (None, 4, 30, 30, 64)     110656
#
#  activation_81 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_123 (Ba  (None, 4, 30, 30, 64)    256
#  tchNormalization)
#
#  max_pooling3d_66 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  dropout_42 (Dropout)        (None, 2, 15, 15, 64)     0
#
#  conv3d_82 (Conv3D)          (None, 2, 15, 15, 128)    221312
#
#  activation_82 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_124 (Ba  (None, 2, 15, 15, 128)   512
#  tchNormalization)
#
#  conv3d_83 (Conv3D)          (None, 2, 15, 15, 128)    442496
#
#  activation_83 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_125 (Ba  (None, 2, 15, 15, 128)   512
#  tchNormalization)
#
#  max_pooling3d_67 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  dropout_43 (Dropout)        (None, 1, 7, 7, 128)      0
#
#  flatten_18 (Flatten)        (None, 6272)              0
#
#  dense_52 (Dense)            (None, 256)               1605888
#
#  batch_normalization_126 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_44 (Dropout)        (None, 256)               0
#
#  dense_53 (Dense)            (None, 256)               65792
#
#  batch_normalization_127 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_45 (Dropout)        (None, 256)               0
#
#  dense_54 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 2,556,533
# Trainable params: 2,554,549
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
print("Total Params:", conv_3d12_model.count_params())
history_model12=conv_3d12.train_model(conv_3d12_model,augment_data=True)
# Out:
# Total Params: 2556533
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.9582 - categorical_accuracy: 0.3379
# Epoch 00001: saving model to model_init_2024-02-0119_35_00.439960/model-00001-1.95823-0.33786-2.04340-0.21000.h5
# 34/34 [==============================] - 392s 12s/step - loss: 1.9582 - categorical_accuracy: 0.3379 - val_loss: 2.0434 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.6061 - categorical_accuracy: 0.4110
# Epoch 00002: saving model to model_init_2024-02-0119_35_00.439960/model-00002-1.60613-0.41101-3.39138-0.17000.h5
# 34/34 [==============================] - 391s 12s/step - loss: 1.6061 - categorical_accuracy: 0.4110 - val_loss: 3.3914 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.3301 - categorical_accuracy: 0.5143
# Epoch 00003: saving model to model_init_2024-02-0119_35_00.439960/model-00003-1.33006-0.51433-3.79787-0.18000.h5
# 34/34 [==============================] - 384s 12s/step - loss: 1.3301 - categorical_accuracy: 0.5143 - val_loss: 3.7979 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2991 - categorical_accuracy: 0.5452
# Epoch 00004: saving model to model_init_2024-02-0119_35_00.439960/model-00004-1.29910-0.54525-4.85851-0.20000.h5
# 34/34 [==============================] - 394s 12s/step - loss: 1.2991 - categorical_accuracy: 0.5452 - val_loss: 4.8585 - val_categorical_accuracy: 0.2000 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1647 - categorical_accuracy: 0.5649
# Epoch 00005: saving model to model_init_2024-02-0119_35_00.439960/model-00005-1.16469-0.56486-5.68581-0.21000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 395s 12s/step - loss: 1.1647 - categorical_accuracy: 0.5649 - val_loss: 5.6858 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 6/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9503 - categorical_accuracy: 0.6388
# Epoch 00006: saving model to model_init_2024-02-0119_35_00.439960/model-00006-0.95034-0.63876-5.70187-0.21000.h5
# 34/34 [==============================] - 387s 12s/step - loss: 0.9503 - categorical_accuracy: 0.6388 - val_loss: 5.7019 - val_categorical_accuracy: 0.2100 - lr: 4.0000e-05
# Epoch 7/25
# 34/34 [==============================] - ETA: 0s - loss: 0.
- lr: 1.6000e-06
# Epoch 18/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8141 - categorical_accuracy: 0.6976
# Epoch 00018: saving model to model_init_2024-02-0119_35_00.439960/model-00018-0.81414-0.69759-4.43823-0.21000.h5
# 34/34 [==============================] - 181s 5s/step - loss: 0.8141 - categorical_accuracy: 0.6976 - val_loss: 4.4382 - val_categorical_accuracy: 0.2100 - lr: 3.2000e-07
# Epoch 19/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7949 - categorical_accuracy: 0.6795
# Epoch 00019: saving model to model_init_2024-02-0119_35_00.439960/model-00019-0.79488-0.67949-4.29266-0.19000.h5
# 34/34 [==============================] - 180s 5s/step - loss: 0.7949 - categorical_accuracy: 0.6795 - val_loss: 4.2927 - val_categorical_accuracy: 0.1900 - lr: 3.2000e-07
# Epoch 20/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8740 - categorical_accuracy: 0.6644
# Epoch 00020: saving model to model_init_2024-02-0119_35_00.439960/model-00020-0.87401-0.66440-4.12668-0.24000.h5
# 34/34 [==============================] - 178s 5s/step - loss: 0.8740 - categorical_accuracy: 0.6644 - val_loss: 4.1267 - val_categorical_accuracy: 0.2400 - lr: 3.2000e-07
# Epoch 21/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8336 - categorical_accuracy: 0.6863
# Epoch 00021: saving model to model_init_2024-02-0119_35_00.439960/model-00021-0.83362-0.68627-4.01661-0.23000.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.399999961104187e-08.
# 34/34 [==============================] - 178s 5s/step - loss: 0.8336 - categorical_accuracy: 0.6863 - val_loss: 4.0166 - val_categorical_accuracy: 0.2300 - lr: 3.2000e-07
# Epoch 22/25
# 34/34 [==============================] - ETA: 0s - loss: 0.7829 - categorical_accuracy: 0.7089
# Epoch 00022: saving model to model_init_2024-02-0119_35_00.439960/model-00022-0.78291-0.70890-4.36091-0.20000.h5
# 34/34 [==============================] - 178s 5s/step - loss: 0.7829 - categorical_accuracy: 0.7089 - val_loss: 4.3609 - val_categorical_accuracy: 0.2000 - lr: 6.4000e-08
# Epoch 23/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8377 - categorical_accuracy: 0.6900
# Epoch 00023: saving model to model_init_2024-02-0119_35_00.439960/model-00023-0.83773-0.69005-3.69293-0.30000.h5
# 34/34 [==============================] - 177s 5s/step - loss: 0.8377 - categorical_accuracy: 0.6900 - val_loss: 3.6929 - val_categorical_accuracy: 0.3000 - lr: 6.4000e-08
# Epoch 24/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8198 - categorical_accuracy: 0.6968
# Epoch 00024: saving model to model_init_2024-02-0119_35_00.439960/model-00024-0.81975-0.69683-3.66163-0.21000.h5
# 34/34 [==============================] - 179s 5s/step - loss: 0.8198 - categorical_accuracy: 0.6968 - val_loss: 3.6616 - val_categorical_accuracy: 0.2100 - lr: 6.4000e-08
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8184 - categorical_accuracy: 0.6817
# Epoch 00025: saving model to model_init_2024-02-0119_35_00.439960/model-00025-0.81842-0.68175-3.78028-0.28000.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.2799999637991278e-08.
# 34/34 [==============================] - 180s 5s/step - loss: 0.8184 - categorical_accuracy: 0.6817 - val_loss: 3.7803 - val_categorical_accuracy: 0.2800 - lr: 6.4000e-08

# %%
plot(history_model12)

# %% [markdown]
# Model is overfitting as we can see in the graph!

# %% [markdown]
# ## Model 13 with Augmentation
# ### Reducing network parameters - Similar to Model 6

# %%
class ModelConv3D13(ModelBuilderMoreAugmentation):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d13=ModelConv3D13()
conv_3d13.initialize_path(project_folder)
conv_3d13.initialize_image_properties(image_height=100,image_width=100)
conv_3d13.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d13_model=conv_3d13.define_model(dense_neurons=128,dropout=0.25)
conv_3d13_model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_84 (Conv3D)          (None, 16, 100, 100, 16)  1312
#
#  activation_84 (Activation)  (None, 16, 100, 100, 16)  0
#
#  batch_normalization_128 (Ba  (None, 16, 100, 100, 16)  64
#  tchNormalization)
#
#  max_pooling3d_68 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_85 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  activation_85 (Activation)  (None, 8, 50, 50, 32)     0
#
#  batch_normalization_129 (Ba  (None, 8, 50, 50, 32)    128
#  tchNormalization)
#
#  max_pooling3d_69 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d_86 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  activation_86 (Activation)  (None, 4, 25, 25, 64)     0
#
#  batch_normalization_130 (Ba  (None, 4, 25, 25, 64)    256
#  tchNormalization)
#
#  max_pooling3d_70 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  conv3d_87 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  activation_87 (Activation)  (None, 2, 12, 12, 128)    0
#
#  batch_normalization_131 (Ba  (None, 2, 12, 12, 128)   512
#  tchNormalization)
#
#  max_pooling3d_71 (MaxPoolin  (None, 1, 6, 6, 128)     0
#  g3D)
#
#  flatten_19 (Flatten)        (None, 4608)              0
#
#  dense_55 (Dense)            (None, 128)               589952
#
#  batch_normalization_132 (Ba  (None, 128)              512
#  tchNormalization)
#
#  dropout_46 (Dropout)        (None, 128)               0
#
#  dense_56 (Dense)            (None, 128)               16512
#
#  batch_normalization_133 (Ba  (None, 128)              512
#  tchNormalization)
#
#  dropout_47 (Dropout)        (None, 128)               0
#
#  dense_57 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 696,645
# Trainable params: 695,653
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", conv_3d13_model.count_params())
history_model13=conv_3d13.train_model(conv_3d13_model,augment_data=True)
# Out:
# Total Params: 696645
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.7884 - categorical_accuracy: 0.3394
# Epoch 00001: saving model to model_init_2024-02-0121_26_17.778967/model-00001-1.78838-0.33937-1.87012-0.16000.h5
# 34/34 [==============================] - 233s 7s/step - loss: 1.7884 - categorical_accuracy: 0.3394 - val_loss: 1.8701 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.1987 - categorical_accuracy: 0.5362
# Epoch 00002: saving model to model_init_2024-02-0121_26_17.778967/model-00002-1.19865-0.53620-2.53327-0.17000.h5
# 34/34 [==============================] - 323s 10s/step - loss: 1.1987 - categorical_accuracy: 0.5362 - val_loss: 2.5333 - val_categorical_accuracy: 0.1700 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 1.0066 - categorical_accuracy: 0.6124
# Epoch 00003: saving model to model_init_2024-02-0121_26_17.778967/model-00003-1.00658-0.61237-3.00704-0.19000.h5
# 34/34 [==============================] - 319s 10s/step - loss: 1.0066 - categorical_accuracy: 0.6124 - val_loss: 3.0070 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.8954 - categorical_accuracy: 0.6667
# Epoch 00004: saving model to model_init_2024-02-0121_26_17.778967/model-00004-0.89541-0.66667-3.92582-0.18000.h5
# 34/34 [==============================] - 322s 10s/step - loss: 0.8954 - categorical_accuracy: 0.6667 - val_loss: 3.9258 - val_categorical_accuracy: 0.1800 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.5832 - categorical_accuracy: 0.7768
# Epoch 00025: saving model to model_init_2024-02-0121_26_17.778967/model-00025-0.58322-0.77677-0.89351-0.68000.h5
# 34/34 [==============================] - 319s 10s/step - loss: 0.5832 - categorical_accuracy: 0.7768 - val_loss: 0.8935 - val_categorical_accuracy: 0.6800 - lr: 1.6000e-06

# %%
plot(history_model13)

# %% [markdown]
# ## Model 14 with Augmentation
# ###  Reducing network parameters again - Similar to model 7

# %%
class ModelConv3D14(ModelBuilderMoreAugmentation):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (3, 3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d14=ModelConv3D14()
conv_3d14.initialize_path(project_folder)
conv_3d14.initialize_image_properties(image_height=120,image_width=120)
conv_3d14.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=25)
conv_3d14_model=conv_3d14.define_model(dense_neurons=64,dropout=0.25)
conv_3d14_model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_88 (Conv3D)          (None, 16, 120, 120, 16)  1312
#
#  activation_88 (Activation)  (None, 16, 120, 120, 16)  0
#
#  batch_normalization_134 (Ba  (None, 16, 120, 120, 16)  64
#  tchNormalization)
#
#  max_pooling3d_72 (MaxPoolin  (None, 8, 60, 60, 16)    0
#  g3D)
#
#  conv3d_89 (Conv3D)          (None, 8, 60, 60, 32)     13856
#
#  activation_89 (Activation)  (None, 8, 60, 60, 32)     0
#
#  batch_normalization_135 (Ba  (None, 8, 60, 60, 32)    128
#  tchNormalization)
#
#  max_pooling3d_73 (MaxPoolin  (None, 4, 30, 30, 32)    0
#  g3D)
#
#  conv3d_90 (Conv3D)          (None, 4, 30, 30, 64)     16448
#
#  activation_90 (Activation)  (None, 4, 30, 30, 64)     0
#
#  batch_normalization_136 (Ba  (None, 4, 30, 30, 64)    256
#  tchNormalization)
#
#  max_pooling3d_74 (MaxPoolin  (None, 2, 15, 15, 64)    0
#  g3D)
#
#  conv3d_91 (Conv3D)          (None, 2, 15, 15, 128)    65664
#
#  activation_91 (Activation)  (None, 2, 15, 15, 128)    0
#
#  batch_normalization_137 (Ba  (None, 2, 15, 15, 128)   512
#  tchNormalization)
#
#  max_pooling3d_75 (MaxPoolin  (None, 1, 7, 7, 128)     0
#  g3D)
#
#  flatten_20 (Flatten)        (None, 6272)              0
#
#  dense_58 (Dense)            (None, 64)                401472
#
#  batch_normalization_138 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dropout_48 (Dropout)        (None, 64)                0
#
#  dense_59 (Dense)            (None, 64)                4160
#
#  batch_normalization_139 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dropout_49 (Dropout)        (None, 64)                0
#
#  dense_60 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 504,709
# Trainable params: 503,973
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d14_model.count_params())
history_model14=conv_3d14.train_model(conv_3d14_model,augment_data=True)
# Out:
# Total Params: 504709
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 34/34 [==============================] - ETA: 0s - loss: 1.8094 - categorical_accuracy: 0.3854
# Epoch 00001: saving model to model_init_2024-02-0123_37_30.613765/model-00001-1.80944-0.38537-2.01967-0.21000.h5
# 34/34 [==============================] - 394s 12s/step - loss: 1.8094 - categorical_accuracy: 0.3854 - val_loss: 2.0197 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/25
# 34/34 [==============================] - ETA: 0s - loss: 1.2032 - categorical_accuracy: 0.5385
# Epoch 00002: saving model to model_init_2024-02-0123_37_30.613765/model-00002-1.20320-0.53846-3.10984-0.21000.h5
# 34/34 [==============================] - 183s 6s/step - loss: 1.2032 - categorical_accuracy: 0.5385 - val_loss: 3.1098 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 3/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9920 - categorical_accuracy: 0.6078
# Epoch 00003: saving model to model_init_2024-02-0123_37_30.613765/model-00003-0.99198-0.60784-4.27279-0.16000.h5
# 34/34 [==============================] - 181s 5s/step - loss: 0.9920 - categorical_accuracy: 0.6078 - val_loss: 4.2728 - val_categorical_accuracy: 0.1600 - lr: 2.0000e-04
# Epoch 4/25
# 34/34 [==============================] - ETA: 0s - loss: 0.9444 - categorical_accuracy: 0.6342
# Epoch 00004: saving model to model_init_2024-02-0123_37_30.613765/model-00004-0.94438-0.63424-4.62372-0.24000.h5
# 34/34 [==============================] - 180s 5s/step - loss: 0.9444 - categorical_accuracy: 0.6342 - val_loss: 4.6237 - val_categorical_accuracy: 0.2400 - lr: 2.0000e-04
# Epoch 5/25
# 34/34 [==============================] - ETA: 0s - loss: 0.
# Epoch 25/25
# 34/34 [==============================] - ETA: 0s - loss: 0.6265 - categorical_accuracy: 0.7805
# Epoch 00025: saving model to model_init_2024-02-0123_37_30.613765/model-00025-0.62651-0.78054-0.67121-0.74000.h5
# 34/34 [==============================] - 391s 12s/step - loss: 0.6265 - categorical_accuracy: 0.7805 - val_loss: 0.6712 - val_categorical_accuracy: 0.7400 - lr: 1.6000e-06

# %%
plot(history_model14)

# %% [markdown]
# ## Model 15 with Augmentation
# ### CNN LSTM with GRU - Similar to Model 8

# %%
class RNNCNN2(ModelBuilderMoreAugmentation):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        

        model.add(TimeDistributed(Flatten()))


        model.add(GRU(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = tf.keras.optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn2=RNNCNN2()
rnn_cnn2.initialize_path(project_folder)
rnn_cnn2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn2.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn2_model=rnn_cnn2.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn2_model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_32 (TimeDi  (None, 18, 120, 120, 16)  448
#  stributed)
#
#  time_distributed_33 (TimeDi  (None, 18, 120, 120, 16)  64
#  stributed)
#
#  time_distributed_34 (TimeDi  (None, 18, 60, 60, 16)   0
#  stributed)
#
#  time_distributed_35 (TimeDi  (None, 18, 60, 60, 32)   4640
#  stributed)
#
#  time_distributed_36 (TimeDi  (None, 18, 60, 60, 32)   128
#  stributed)
#
#  time_distributed_37 (TimeDi  (None, 18, 30, 30, 32)   0
#  stributed)
#
#  time_distributed_38 (TimeDi  (None, 18, 30, 30, 64)   18496
#  stributed)
#
#  time_distributed_39 (TimeDi  (None, 18, 30, 30, 64)   256
#  stributed)
#
#  time_distributed_40 (TimeDi  (None, 18, 15, 15, 64)   0
#  stributed)
#
#  time_distributed_41 (TimeDi  (None, 18, 15, 15, 128)  73856
#  stributed)
#
#  time_distributed_42 (TimeDi  (None, 18, 15, 15, 128)  512
#  stributed)
#
#  time_distributed_43 (TimeDi  (None, 18, 7, 7, 128)    0
#  stributed)
#
#  time_distributed_44 (TimeDi  (None, 18, 6272)         0
#  stributed)
#
#  gru (GRU)                   (None, 128)               2458368
#
#  dropout_50 (Dropout)        (None, 128)               0
#
#  dense_61 (Dense)            (None, 128)               16512
#
#  dropout_51 (Dropout)        (None, 128)               0
#
#  dense_62 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 2,573,925
# Trainable params: 2,573,445
# Non-trainable params: 480
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn2_model.count_params())
history_model15=rnn_cnn2.train_model(rnn_cnn2_model,augment_data=True)
# Out:
# Total Params: 2573925
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.4613 - categorical_accuracy: 0.3597
# Epoch 00001: saving model to model_init_2024-02-0201_55_44.281429/model-00001-1.46126-0.35973-1.63393-0.21000.h5
# 34/34 [==============================] - 457s 14s/step - loss: 1.4613 - categorical_accuracy: 0.3597 - val_loss: 1.6339 - val_categorical_accuracy: 0.2100 - lr: 2.0000e-04
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 1.0612 - categorical_accuracy: 0.5716
# Epoch 00002: saving model to model_init_2024-02-0201_55_44.281429/model-00002-1.06124-0.57164-1.71142-0.19000.h5
# 34/34 [==============================] - 205s 6s/step - loss: 1.0612 - categorical_accuracy: 0.5716 - val_loss: 1.7114 - val_categorical_accuracy: 0.1900 - lr: 2.0000e-04
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.8568 - categorical_accuracy: 0.6569
# Epoch 00003: saving model to model_init_2024-02-0201_55_44.281429/model-00003-0.85680-0.65686-1.71397-0.23000.h5
# 34/34 [==============================] - 207s 6s/step - loss: 0.8568 - categorical_accuracy: 0.6569 - val_loss: 1.7140 - val_categorical_accuracy: 0.2300 - lr: 2.0000e-04
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.
20
# 34/34 [==============================] - ETA: 0s - loss: 0.2821 - categorical_accuracy: 0.9216
# Epoch 00013: saving model to model_init_2024-02-0201_55_44.281429/model-00013-0.28209-0.92157-1.34650-0.48000.h5
# 34/34 [==============================] - 204s 6s/step - loss: 0.2821 - categorical_accuracy: 0.9216 - val_loss: 1.3465 - val_categorical_accuracy: 0.4800 - lr: 8.0000e-06
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2936 - categorical_accuracy: 0.9148
# Epoch 00014: saving model to model_init_2024-02-0201_55_44.281429/model-00014-0.29357-0.91478-1.14680-0.52000.h5
# 34/34 [==============================] - 199s 6s/step - loss: 0.2936 - categorical_accuracy: 0.9148 - val_loss: 1.1468 - val_categorical_accuracy: 0.5200 - lr: 8.0000e-06
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2765 - categorical_accuracy: 0.9291
# Epoch 00015: saving model to model_init_2024-02-0201_55_44.281429/model-00015-0.27648-0.92911-1.00170-0.56000.h5
# 34/34 [==============================] - 202s 6s/step - loss: 0.2765 - categorical_accuracy: 0.9291 - val_loss: 1.0017 - val_categorical_accuracy: 0.5600 - lr: 8.0000e-06
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2627 - categorical_accuracy: 0.9268
# Epoch 00016: saving model to model_init_2024-02-0201_55_44.281429/model-00016-0.26272-0.92685-0.90338-0.60000.h5
# 34/34 [==============================] - 202s 6s/step - loss: 0.2627 - categorical_accuracy: 0.9268 - val_loss: 0.9034 - val_categorical_accuracy: 0.6000 - lr: 8.0000e-06
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2619 - categorical_accuracy: 0.9276
# Epoch 00017: saving model to model_init_2024-02-0201_55_44.281429/model-00017-0.26194-0.92760-0.73906-0.62000.h5
# 34/34 [==============================] - 202s 6s/step - loss: 0.2619 - categorical_accuracy: 0.9276 - val_loss: 0.7391 - val_categorical_accuracy: 0.6200 - lr: 8.0000e-06
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2674 - categorical_accuracy: 0.9253
# Epoch 00018: saving model to model_init_2024-02-0201_55_44.281429/model-00018-0.26739-0.92534-0.78878-0.69000.h5
# 34/34 [==============================] - 203s 6s/step - loss: 0.2674 - categorical_accuracy: 0.9253 - val_loss: 0.7888 - val_categorical_accuracy: 0.6900 - lr: 8.0000e-06
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2585 - categorical_accuracy: 0.9291
# Epoch 00019: saving model to model_init_2024-02-0201_55_44.281429/model-00019-0.25848-0.92911-0.72546-0.70000.h5
# 34/34 [==============================] - 429s 13s/step - loss: 0.2585 - categorical_accuracy: 0.9291 - val_loss: 0.7255 - val_categorical_accuracy: 0.7000 - lr: 8.0000e-06
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2612 - categorical_accuracy: 0.9268
# Epoch 00020: saving model to model_init_2024-02-0201_55_44.281429/model-00020-0.26117-0.92685-0.56503-0.80000.h5
# 34/34 [==============================] - 439s 13s/step - loss: 0.2612 - categorical_accuracy: 0.9268 - val_loss: 0.5650 - val_categorical_accuracy: 0.8000 - lr: 8.0000e-06

# %%
plot(history_model15)

# %% [markdown]
# ### We see that overfitting is considerably high when we do more augmentation. However there is not much improvement on accuracy

# %% [markdown]
# ## Model 16 - Let us bring in Transfer Learning !! :)
# __(Optional)__

# %%
# importing the MobileNet model due to it's lightweight architecture and high speed performance as compared 
# to other heavy-duty models like VGG16, Alexnet, InceptionV3 etc. Also, we are now also running on low disk space 
# in the nimblebox.ai platform. 

from keras.applications import mobilenet

# %%
mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL(ModelBuilderMoreAugmentation):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):
        
        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        
        
        for layer in model.layers:
            layer.trainable = False
        
        
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        
        
        optimiser = tf.keras.optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 2s 0us/step
# 17235968/17225924 [==============================] - 2s 0us/step

# %%
rnn_cnn_tl=RNNCNN_TL()
rnn_cnn_tl.initialize_path(project_folder)
rnn_cnn_tl.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl_model=rnn_cnn_tl.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl_model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_45 (TimeDi  (None, 16, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_46 (TimeDi  (None, 16, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_47 (TimeDi  (None, 16, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_48 (TimeDi  (None, 16, 1024)         0
#  stributed)
#
#  lstm_2 (LSTM)               (None, 128)               590336
#
#  dropout_52 (Dropout)        (None, 128)               0
#
#  dense_63 (Dense)            (None, 128)               16512
#
#  dropout_53 (Dropout)        (None, 128)               0
#
#  dense_64 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,840,453
# Trainable params: 609,541
# Non-trainable params: 3,230,912
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn_tl_model.count_params())
history_model16=rnn_cnn_tl.train_model(rnn_cnn_tl_model,augment_data=True)
# Out:
# Total Params: 3840453
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 133/133 [==============================] - ETA: 0s - loss: 1.3707 - categorical_accuracy: 0.4193
# Epoch 00001: saving model to model_init_2024-02-0203_15_37.409559/model-00001-1.37071-0.41931-1.08960-0.56000.h5
# 133/133 [==============================] - 306s 2s/step - loss: 1.3707 - categorical_accuracy: 0.4193 - val_loss: 1.0896 - val_categorical_accuracy: 0.5600 - lr: 0.0010
# Epoch 2/20
# 133/133 [==============================] - ETA: 0s - loss: 0.9391 - categorical_accuracy: 0.6508
# Epoch 00002: saving model to model_init_2024-02-0203_15_37.409559/model-00002-0.93915-0.65083-0.75595-0.69000.h5
# 133/133 [==============================] - 302s 2s/step - loss: 0.9391 - categorical_accuracy: 0.6508 - val_loss: 0.7559 - val_categorical_accuracy: 0.6900 - lr: 0.0010
# Epoch 3/20
# 133/133 [==============================] - ETA: 0s - loss: 0.6793 - categorical_accuracy: 0.7360
# Epoch 00003: saving model to model_init_2024-02-0203_15_37.409559/model-00003-0.67935-0.73605-0.70349-0.72000.h5
# 133/133 [==============================] - 297s 2s/step - loss: 0.6793 - categorical_accuracy: 0.7360 - val_loss: 0.7035 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 4/20
# 133/133 [==============================] - ETA: 0s - loss: 0.5608 - categorical_accuracy: 0.7828
# Epoch 00004: saving model to model_init_2024-02-0203_15_37.409559/model-00004-0.56076-0.78281-0.73915-0.75000.h5
# 133/133 [==============================] - 287s 2s/step - loss: 0.5608 - categorical_accuracy: 0.7828 - val_loss: 0.7392 - val_categorical_accuracy: 0.7500 - lr: 0.0010
20
# 133/133 [==============================] - ETA: 0s - loss: 0.0691 - categorical_accuracy: 0.9796
# Epoch 00013: saving model to model_init_2024-02-0203_15_37.409559/model-00013-0.06914-0.97964-0.83273-0.80000.h5
# 133/133 [==============================] - 267s 2s/step - loss: 0.0691 - categorical_accuracy: 0.9796 - val_loss: 0.8327 - val_categorical_accuracy: 0.8000 - lr: 2.0000e-04
# Epoch 14/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0680 - categorical_accuracy: 0.9774
# Epoch 00014: saving model to model_init_2024-02-0203_15_37.409559/model-00014-0.06798-0.97738-0.73169-0.76000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 133/133 [==============================] - 294s 2s/step - loss: 0.0680 - categorical_accuracy: 0.9774 - val_loss: 0.7317 - val_categorical_accuracy: 0.7600 - lr: 2.0000e-04
# Epoch 15/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0745 - categorical_accuracy: 0.9774
# Epoch 00015: saving model to model_init_2024-02-0203_15_37.409559/model-00015-0.07453-0.97738-0.76268-0.75000.h5
# 133/133 [==============================] - 233s 2s/step - loss: 0.0745 - categorical_accuracy: 0.9774 - val_loss: 0.7627 - val_categorical_accuracy: 0.7500 - lr: 4.0000e-05
# Epoch 16/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0524 - categorical_accuracy: 0.9879
# Epoch 00016: saving model to model_init_2024-02-0203_15_37.409559/model-00016-0.05238-0.98793-0.72177-0.82000.h5
# 133/133 [==============================] - 242s 2s/step - loss: 0.0524 - categorical_accuracy: 0.9879 - val_loss: 0.7218 - val_categorical_accuracy: 0.8200 - lr: 4.0000e-05
# Epoch 17/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0624 - categorical_accuracy: 0.9796
# Epoch 00017: saving model to model_init_2024-02-0203_15_37.409559/model-00017-0.06236-0.97964-0.80633-0.73000.h5
# 133/133 [==============================] - 254s 2s/step - loss: 0.0624 - categorical_accuracy: 0.9796 - val_loss: 0.8063 - val_categorical_accuracy: 0.7300 - lr: 4.0000e-05
# Epoch 18/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0552 - categorical_accuracy: 0.9849
# Epoch 00018: saving model to model_init_2024-02-0203_15_37.409559/model-00018-0.05515-0.98492-0.71748-0.81000.h5
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 133/133 [==============================] - 242s 2s/step - loss: 0.0552 - categorical_accuracy: 0.9849 - val_loss: 0.7175 - val_categorical_accuracy: 0.8100 - lr: 4.0000e-05
# Epoch 19/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0504 - categorical_accuracy: 0.9864
# Epoch 00019: saving model to model_init_2024-02-0203_15_37.409559/model-00019-0.05042-0.98643-0.72221-0.76000.h5
# 133/133 [==============================] - 233s 2s/step - loss: 0.0504 - categorical_accuracy: 0.9864 - val_loss: 0.7222 - val_categorical_accuracy: 0.7600 - lr: 8.0000e-06
# Epoch 20/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0468 - categorical_accuracy: 0.9827
# Epoch 00020: saving model to model_init_2024-02-0203_15_37.409559/model-00020-0.04681-0.98265-0.85864-0.76000.h5
# 133/133 [==============================] - 239s 2s/step - loss: 0.0468 - categorical_accuracy: 0.9827 - val_loss: 0.8586 - val_categorical_accuracy: 0.7600 - lr: 8.0000e-06

# %%
plot(history_model16)

# %% [markdown]
# ##### We are not training the mobilenet weights and we see validation accuracy is very poor. Let's train them as well and observe if there is performance improvement

# %% [markdown]
# ## Model 17 - Transfer Learning with GRU and training all weights
# __(Optional)__

# %%
from keras.applications import mobilenet

mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL2(ModelBuilderMoreAugmentation):
    
    def define_model(self,gru_cells=64,dense_neurons=64,dropout=0.25):
        
        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
 
        
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(GRU(gru_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        
        
        optimiser = tf.keras.optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
rnn_cnn_tl2=RNNCNN_TL2()
rnn_cnn_tl2.initialize_path(project_folder)
rnn_cnn_tl2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl2.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl2_model=rnn_cnn_tl2.define_model(gru_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl2_model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_49 (TimeDi  (None, 16, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_50 (TimeDi  (None, 16, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_51 (TimeDi  (None, 16, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_52 (TimeDi  (None, 16, 1024)         0
#  stributed)
#
#  gru_1 (GRU)                 (None, 128)               443136
#
#  dropout_54 (Dropout)        (None, 128)               0
#
#  dense_65 (Dense)            (None, 128)               16512
#
#  dropout_55 (Dropout)        (None, 128)               0
#
#  dense_66 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn_tl2_model.count_params())
history_model17=rnn_cnn_tl2.train_model(rnn_cnn_tl2_model,augment_data=True)
# Out:
# Total Params: 3693253
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 133/133 [==============================] - ETA: 0s - loss: 1.2269 - categorical_accuracy: 0.4962
# Epoch 00001: saving model to model_init_2024-02-0204_50_35.862866/model-00001-1.22686-0.49623-0.62752-0.75000.h5
# 133/133 [==============================] - 315s 2s/step - loss: 1.2269 - categorical_accuracy: 0.4962 - val_loss: 0.6275 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 2/20
# 133/133 [==============================] - ETA: 0s - loss: 0.7616 - categorical_accuracy: 0.6765
# Epoch 00002: saving model to model_init_2024-02-0204_50_35.862866/model-00002-0.76160-0.67647-0.49445-0.80000.h5
# 133/133 [==============================] - 317s 2s/step - loss: 0.7616 - categorical_accuracy: 0.6765 - val_loss: 0.4945 - val_categorical_accuracy: 0.8000 - lr: 0.0010
# Epoch 3/20
#  51/133 [==========>...................] - ETA: 3:13 - loss: 0.4957 - categorical_accuracy: 0.7765

# %%
plot(history_model17)

# %% [markdown]
# # Consolidated Final Models

# %% [markdown]
# ## After doing all the experiments, we finalized Model 8 - CNN+LSTM, which performed well.

# %% [markdown]
# # Loading model and Testing

# %%
import time
from keras.models import load_model
model = load_model('model_init_2024-07-2522_00_52.036987/model-00001-1.22686-0.49623-0.62752-0.75000.h5')

# %%
test_generator=RNNCNN1()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=120,image_width=120)
test_generator.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=False)
batch_data, batch_labels=next(g)

# %%
batch_labels

# %%
print(np.argmax(model.predict(batch_data[:,:,:,:,:]),axis=1))
